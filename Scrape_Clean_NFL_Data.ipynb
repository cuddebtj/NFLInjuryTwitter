# %%
import dash, requests, os
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
import datetime as dt
from bs4 import BeautifulSoup
import numpy as np
from dotenv import load_dotenv
load_dotenv()
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)




def team_data_scrape(Start_Year,End_Year,url):
    page = 0
    stat_login_url = "https://stathead.com/users/login.cgi"
    stat_user_name = os.environ.get('statheadusername')
    stat_password = os.environ.get('statheadpassword')
    stat_payload = {
        'username': stat_user_name,
        'password': stat_password
    }
    
    if url == 1:
        stat_url = 'https://stathead.com/football/tgl_finder.cgi?request=1&temperature_gtlt=lt&game_num_max=99&week_num_max=99&order_by=points&match=game&year_max={End_Year}&order_by_asc=0&week_num_min=0&game_type=E&game_num_min=0&year_min={Start_Year}&cstat[1]=all_td_team&ccomp[1]=gt&cval[1]=0&cstat[2]=third_down_att&ccomp[2]=gt&cval[2]=0&cstat[3]=vegas_line&ccomp[3]=gt&cval[3]=-50&cstat[4]=penalties&ccomp[4]=gt&cval[4]=0&cstat[5]=rush_att&ccomp[5]=gt&cval[5]=0&cstat[6]=tot_yds&ccomp[6]=gt&cval[6]=0&cstat[7]=first_down&ccomp[7]=gt&cval[7]=0&cstat[8]=punt&ccomp[8]=gt&cval[8]=0&cstat[9]=pass_cmp&ccomp[9]=gt&cval[9]=0&offset={page}'
    elif url == 2:
        stat_url = 'https://stathead.com/football/tgl_finder.cgi?request=1&temperature_gtlt=lt&game_num_max=99&week_num_max=99&order_by=all_td_opp&match=game&year_max={End_Year}&order_by_asc=0&week_num_min=0&game_type=R&game_num_min=0&year_min={Start_Year}&cstat[1]=tot_yds_opp&ccomp[1]=gt&cval[1]=0&cstat[2]=rush_yds_diff&ccomp[2]=gt&cval[2]=-500&cstat[3]=score_diff_thru_1&ccomp[3]=gt&cval[3]=-500&cstat[4]=rush_att_opp&ccomp[4]=gt&cval[4]=0&cstat[5]=kick_ret_td_tgl&ccomp[5]=gt&cval[5]=0&cstat[6]=pass_cmp_opp&ccomp[6]=gt&cval[6]=0&cstat[7]=first_down_opp&ccomp[7]=gt&cval[7]=0&cstat[8]=score_diff_1_qtr&ccomp[8]=gt&cval[8]=-500&cstat[9]=third_down_att_opp&ccomp[9]=gt&cval[9]=0&offset={page}'
    elif url != 1 or 2:
        print("Please select 1 or 2.")
        
    with requests.Session() as session:
        
        s = session.post(stat_login_url, data=stat_payload)
        
        while page < 100000:
            
            website = session.get(stat_url.format(Start_Year=Start_Year,End_Year=End_Year,page=page)).text
            soup = BeautifulSoup(website, 'html')
            table = soup.find('table', attrs={'class': 'sortable', 'id': 'results'})

            table_headers = [header.text for header in table.find('thead').find_all('th')]
            table_rows = table.find_all('tr')

            final_data = []
            
            for tr in table_rows:
                td = tr.find_all('td')
                row = [tr.text for tr in td]
                final_data.append(row)
                
            df = pd.DataFrame(final_data[1:], columns=table_headers[12:])
            
            print(page)
            
            if url == 1:
                df.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_1_{Start_Year}_{End_Year}.csv',mode='a',index=False)
            else:
                df.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_2_{Start_Year}_{End_Year}.csv',mode='a',index=False)

            page += 100
                
        print('Done')
        print(page)

        
        
        
def player_snap_scrape(Start_Year,End_Year):
    
    sides = ['','defense.php']
    
    ENDPOINT = "https://www.fantasypros.com/nfl/reports/snap-counts/{side}?year={year}"

    final_df = pd.DataFrame()

    for year in range(Start_Year, End_Year+1):
        
        for side in sides:
        
            res = requests.get(ENDPOINT.format(year=year,side=side))

            soup = BeautifulSoup(res.content, 'html.parser')

            table = soup.find('table', {'id': 'data'})

            df = pd.read_html(str(table))[0]

            df.columns = df.columns[:3].tolist() + [f'Week {i}' for i in df.columns[3:-2]] + df.columns[-2:].tolist()

            df['Year'] = year

            cols = df.columns[:3].tolist() + df.columns[-1:].tolist() + df.columns[3:-1].tolist()
            df = df[cols]

            final_df = pd.concat([final_df, df])
            print(year,side)

    final_df.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\snapcounts_{Start_Year}_{End_Year}.csv',index=False)
    print('Done')

    
    
    
def injury_reports_scrape(Start_Year,End_Year):
    
    teams = ['crd', 'atl', 'rav', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb','htx','clt','jax','kan',
             'sdg','ram','mia','min','nor','nwe','nyg','nyj','rai','phi','pit','sea','sfo','tam','oti','was']

    ENDPOINT = 'https://www.pro-football-reference.com/teams/{team}/{year}_injuries.htm'

    final_df = pd.DataFrame()

    for year in range(Start_Year, End_Year+1):

        for team in teams:

            res = requests.get(ENDPOINT.format(year=year,team=team))

            soup = BeautifulSoup(res.content, 'lxml')

            table = soup.find('table', attrs={'class': 'sortable', 'id': 'team_injuries'})
            table_rows = table.find_all('tr')

            final_data = []
            for tr in table_rows:
                td = tr.find_all(['th','td'])
                row = [tr['data-tip'] if tr.has_attr("data-tip") else tr.text for tr in td]
                final_data.append(row)

            dfdata = final_data[1:]
            data_body = [[dfdata[j][i] for j in range(len(dfdata))] for i in range(len(dfdata[0]))]

            df = pd.DataFrame(data_body,final_data[0]).T

            df.insert(loc=1,column='Team',value=team)
            df.insert(loc=2,column='Year',value=year)

            final_df = pd.concat([final_df, df])
            final_df.rename(columns={'PlayerÂ ':'Player'},inplace=True)
            print(team,year)

    final_df.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nlf_injuryreport_{Start_Year}_{End_Year}.csv',index=False)
    print('Done')    

    
    
    
def player_stats_scape(Start_Year,End_Year):
    page = 0
    location = 5000
    stat_login_url = "https://stathead.com/users/login.cgi"
    stat_user_name = os.environ.get('statheadusername')
    stat_password = os.environ.get('statheadpassword')
    stat_payload = {
        'username': stat_user_name,
        'password': stat_password
    }
    stat_url = "https://stathead.com/football/pgl_finder.cgi?request=1&game_num_max=99&week_num_max=99&order_by=all_td&season_start=1&qb_gwd=0&order_by_asc=0&qb_comeback=0&week_num_min=0&game_num_min=0&year_min={Start_Year}&match=game&year_max={End_Year}&season_end=-1&age_min=0&game_type=R&age_max=99&positions[]=qb&positions[]=rb&positions[]=wr&positions[]=te&positions[]=e&positions[]=t&positions[]=g&positions[]=c&positions[]=ol&positions[]=dt&positions[]=de&positions[]=dl&positions[]=ilb&positions[]=olb&positions[]=lb&positions[]=cb&positions[]=s&positions[]=db&positions[]=k&positions[]=p&cstat[1]=punt_ret&ccomp[1]=gt&cval[1]=0&cstat[2]=sacks&ccomp[2]=gt&cval[2]=0&cstat[3]=fumbles&ccomp[3]=gt&cval[3]=0&cstat[4]=rush_att&ccomp[4]=gt&cval[4]=0&cstat[5]=pass_defended&ccomp[5]=gt&cval[5]=0&cstat[6]=pass_cmp&ccomp[6]=gt&cval[6]=0&cstat[7]=targets&ccomp[7]=gt&cval[7]=0&cstat[8]=kick_ret&ccomp[8]=gt&cval[8]=0&offset={page}"
    
    with requests.Session() as session:
        
        s = session.post(stat_login_url, data=stat_payload)
        
        while page < 100000:
            
            website = session.get(stat_url.format(Start_Year=Start_Year,End_Year=End_Year,page=page)).text
            soup = BeautifulSoup(website, 'html')
            table = soup.find('table', attrs={'class': 'sortable', 'id': 'results'})

            table_headers = [header.text for header in table.find('thead').find_all('th')]
            table_rows = table.find_all('tr')

            final_data = []
            
            for tr in table_rows:
                td = tr.find_all('td')
                row = [tr.text for tr in td]
                final_data.append(row)
                
            df = pd.DataFrame(final_data[1:], columns=table_headers[11:])
            df.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\player_stats_{Start_Year}_{End_Year}.csv',mode='a',index=False)

            if page > location:
                print(page)
                location += 5000
                
            page += 100
            
        print('Done')
        print(page)

        
        
        
def data_clean(Start_Year,End_Year):
    
    snaps = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\snapcounts_{Start_Year}_{End_Year}.csv')
    snaps.drop(['Unnamed: 0','TTL','AVG'],axis=1,inplace=True)
    snaps = pd.melt(snaps, id_vars=['Player','Pos','Team','Year'], var_name='Week', value_name='Snaps')
    snaps['Year'] = snaps['Year'].astype(str)
    snaps['Player'] = snaps['Player'].astype(str)
    snaps['Week'] = snaps['Week'].astype(str)
    snaps.replace({'Team':{'FA':'','GB':'GNB','JAC':'JAX','KC':'KAN','Multi':'','NE':'NWE','NO':'NOR','SF':'SFO','TB':'TAM'},\
                    'Week':{'Week 1':'1','Week 2':'2','Week 3':'3','Week 4':'4','Week 5':'5','Week 6':'6',\
                            'Week 7':'7','Week 8':'8','Week 9':'9','Week 10':'10','Week 11':'11','Week 12':'12',\
                            'Week 13':'13','Week 14':'14','Week 15':'15','Week 16':'16','Week 17':'17'}},inplace=True)
    snaps['Player'] = snaps['Player']+' '
    snaps.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
    snaps['Player'] = snaps['Player'].str.strip(' ')
    
    
    stats = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\player_stats_{Start_Year}_{End_Year}.csv')
    stats.dropna(how='all',inplace=True)
    stats.set_index('Player',inplace=True)
    stats.drop('Player',inplace=True)
    stats.reset_index(inplace=True)
    stats.drop('Lg',axis=1,inplace=True)
    stats.rename(columns={'Tm':'Team','Unnamed: 6':'Away_Home','Cmp':'IPass_Cmp','Att':'IPass_Att','Cmp%':'IPass_Cmp%','Yds':'IPass_Yds',\
                 'TD':'IPass_TD','Int':'IPass_Int','Rate':'IQB_Rate','Sk':'I_Sk','Yds.1':'ISk_Yds','Y/A':'IPass_Y/A',\
                 'AY/A':'IPass_AdjY/A','Att.1':'IRush_Att','Yds.2':'IRush_Yds','Y/A.1':'IRush_Y/A','TD.1':'IRush_TD',\
                 'Tgt':'IRec_Tgt','Rec':'IRec_Rec','Yds.3':'IRec_Yds','Y/R':'IRec_Y/R','TD.2':'IRec_TD','Ctch%':'IRec_Ctch%',\
                 'Y/Tgt':'IRec_Y/Tgt','XPM':'IXP_Made','XPA':'IXP_Att','XP%':'IXP%','FGM':'IFG_Made','FGA':'IFG_Att',\
                 'FG%':'IFG%','2PM':'I2pt_Made','Sfty':'ISfty','TD.3':'ITot_TD','Pts':'ITot_Pts','Rt':'IKR_Rt','Yds.4':'IKR_Yds',\
                 'Y/Rt':'IKR_Y/Rt','TD.4':'IKR_TD','Ret':'IPR_Rt','Yds.5':'IPR_Yds','Y/R.1':'IPR_Y/Rt','TD.5':'IPR_TD',\
                 'Sk.1':'ITack_Sk','Solo':'ITack_Solo','Ast':'ITack_Ast','Comb':'ITack_Tot','TFL':'ITack_TFL',\
                 'QBHits':'ITack_QBHits','Int.1':'IDef_Int','Yds.6':'IDef_IntYds','TD.6':'IDef_IntTD','PD':'IDef_PD',\
                 'Fmb':'IFmb_Fmb','FL':'IFmb_Lost','FF':'IFmb_Forced','FR':'IFmb_Recov','Yds.7':'IFmb_Yds','TD.7':'IFmb_TD'},\
                 inplace=True)

    stats_cols = []
    for col in stats.columns:
        stats_cols.append(col)

    stats.replace({'Away_Home':{'@':'Away',None:'Home'}},inplace=True)
    stats[['IPass_Cmp','IPass_Att','IRec_Rec','IRec_Tgt','IXP_Made','IXP_Att','IFG_Made','IFG_Att']] = stats[['IPass_Cmp','IPass_Att','IRec_Rec','IRec_Tgt','IXP_Made','IXP_Att','IFG_Made','IFG_Att']].astype(float)
    stats['IPass_Cmp%'] = stats['IPass_Cmp']/stats['IPass_Att']
    stats['IRec_Ctch%'] = stats['IRec_Rec']/stats['IRec_Tgt']
    stats['IXP%'] = stats['IXP_Made']/stats['IXP_Att']
    stats['IFG%'] = stats['IFG_Made']/stats['IFG_Att']
    stats[stats_cols[11:]] = stats[stats_cols[11:]].astype(float)
    stats[stats_cols[11:]] = stats[stats_cols[11:]].fillna(value=0)
    stats['Date'] = pd.to_datetime(stats['Date'],errors='coerce',format='%Y-%m-%d')
    stats.insert(loc=8,column='Year',value=stats['Date'].dt.year)
    stats['Player'] = stats['Player'].astype(str)
    stats['Week'] = stats['Week'].astype(str)
    stats['Year'] = stats['Year'].astype(str)
    stats['Player'] = stats['Player']+' '
    stats.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
    stats['Player'] = stats['Player'].str.strip(' ')
    
    
    
    team1 = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_1_{Start_Year}_{End_Year}.csv')
    team2 = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_2_{Start_Year}_{End_Year}.csv')
    team1.dropna(thresh=10,inplace=True)
    team2.dropna(thresh=10,inplace=True)
    team1.drop('LTime',axis=1,inplace=True)
    team2.drop(['LTime'],axis=1,inplace=True)
    test1 = team1.columns
    test2 = team2.columns
    team1.rename(columns={'Tm':'Team','Unnamed: 5':'Away_Home','PF':'Points_For','PA':'Points_Against','PC':'Points_Comb',\
                         'vs. Line':'Vs_Line','Cmp':'TPass_Cmp','Att':'TPass_Att','Cmp%':'TPass_Cmp%','Yds':'TPass_Yds',\
                          'TD':'TPass_TD','Int':'TPass_Int','Sk':'TSack','Yds.1':'TSack_Yds','Rate':'TQB_Rate',\
                          'Att.1':'TRush_Att','Yds.2':'TRush_Yds','Y/A':'TRush_Y/A','TD.1':'TRush_TD','Tot':'TTot_Yds',\
                          'Ply':'TO_Play#','Y/P':'TO_Y/P','DPly':'TD_Play#','DY/P':'TD_Y/P','TO':'TTot_TO','ToP':'TO_ToP',\
                          'Time.1':'TGame_Dur','Yds.3':'TPen_Yds','OppPen':'TOpp_Pen','OppYds':'TOpp_Pen_Yds',\
                          'CombPen':'TComb_Pen','CombPenYds':'TComb_Pen_Yds','1stD':'T1st_Downs','Rsh':'T1st_by_Rsh',\
                          'Pass':'T1st_by_Pass','Pen.1':'T1st_by_Pen','3DAtt':'T3rd_Down_Att','3DConv':'T3rd_Down_Conv',\
                          '3D%':'T3rd_Down%','4DAtt':'T4th_Down_Att','4DConv':'T4th_Down_Conv','4D%':'T4th_Down%',\
                          'TD.2':'TTot_TD','XPA':'TXP_Att','XPM':'TXP_Made','FGA':'TFG_Att','FGM':'TFG_Made','2PA':'T2Pt_Att',\
                          '2PM':'T2Pt_Made','Sfty':'TSfty','Pnt':'TTimes_Punted','Yds.4':'TPunt_Yds','Y/P.1':'TPunt_Yds_Avg'},inplace=True)
    team2.rename(columns={'Tm':'Team','Unnamed: 5':'Away_Home','TD':'TOpp_Tot_TD','XPA':'TOpp_XP_Att','XPM':'TOpp_XP_Made',\
                          'Att':'TOpp_FG_Att','Md':'TOpp_FG_Made','Sfty':'TOpp_Sfty','Cmp':'TOpp_Pass_Cmp','Att.1':'TOpp_Pass_Att',\
                          'Cmp%':'TOpp_Pass_Cmp%','Yds':'TOpp_Pass_Yds','TD.1':'TOpp_Pass_TD','Int':'TOpp_Pass_Int','Sk':'TOpp_Sk',\
                          'Yds.1':'TOpp_Sk_Yds','Rate':'TOpp_QB_Rate','Att.2':'TOpp_Rush_Att','Yds.2':'TOpp_Rush_Yds',\
                          'Y/A':'TOpp_Rush_Y/A','TD.2':'TOpp_Rush_TD','Tot':'TOpp_Tot_Yds','TO':'TOpp_Tot_TO',\
                          '1stDOpp':'TOpp_1st_Downs','Rush':'TOpp_1st_by_Rsh','Pass':'TOpp_1st_by_Pass','Pen':'TOpp_1st_by_Pen',\
                          'Opp3DAtt':'TOpp_3rd_Down_Att','Opp3DConv':'TOpp_3rd_Down_Conv','Opp3D%':'TOpp_3rd_Down%',\
                          'Opp4DAtt':'TOpp_4th_Down_Att','Opp4DConv':'TOpp_4th_Down_Conv','Opp4D%':'TOpp_4th_Down%',\
                          'Rush.1':'TMargin_Rush','Pass.1':'TMargin_Pass','Tot.1':'TMargin_TotYds','TO.1':'TTO_TD',\
                          'KR':'TKR_TD','PR':'TPR_TD','IR':'TInt_TD','FR':'TFmb_TD','OR':'TOtherRet_TD',\
                          'RetTD':'TAll_Ret_TD','Q1':'TMar_Thru_Q1','Q2':'TMar_Thru_Q2','Q3':'TMar_Thru_Q3',\
                          'Q1.1':'TScore_Diff_Q1','Q2.1':'TScore_Diff_Q2','Q3.1':'TScore_Diff_Q3',\
                          'Q4':'TScore_Diff_Q4','1stHalf':'TScore_Diff_1stHalf','2ndHalf':'TScore_Diff_2ndHalf'},inplace=True)

    team = pd.merge(left=team1,right=team2,\
                     how='outer',\
                     on=['Team','Year','Date','Time','Away_Home','Opp','Week','G#','Day','Result','OT'])

    team.set_index('Team',inplace=True)
    team.drop('Tm',inplace=True)
    team.reset_index(inplace=True)

    team_cols = []

    for col in team.columns:
        team_cols.append(col)

    team.replace({'Away_Home':{'@':'Away',None:'Home'}},inplace=True)
    team[team_cols[11:]] = team[team_cols[11:]].fillna(value=0)
    team[['TPass_Cmp','TPass_Att','T3rd_Down_Att','T3rd_Down_Conv','T4th_Down_Att',\
          'T4th_Down_Conv','TOpp_Pass_Cmp','TOpp_Pass_Att','TOpp_3rd_Down_Att',\
          'TOpp_3rd_Down_Conv','TOpp_4th_Down_Att','TOpp_4th_Down_Conv']] = team[['TPass_Cmp','TPass_Att','T3rd_Down_Att',\
                                                                                  'T3rd_Down_Conv','T4th_Down_Att',\
                                                                                  'T4th_Down_Conv','TOpp_Pass_Cmp',\
                                                                                  'TOpp_Pass_Att','TOpp_3rd_Down_Att',\
                                                                                  'TOpp_3rd_Down_Conv','TOpp_4th_Down_Att',\
                                                                                  'TOpp_4th_Down_Conv']].astype(float)
    team['TPass_Cmp%'] = team['TPass_Cmp']/team['TPass_Att']
    team['T3rd_Down%'] = team['T3rd_Down_Conv']/team['T3rd_Down_Att']
    team['T4th_Down%'] = team['T4th_Down_Conv']/team['T4th_Down_Att']
    team['TOpp_Pass_Cmp%'] = team['TOpp_Pass_Cmp']/team['TOpp_Pass_Att']
    team['TOpp_3rd_Down%'] = team['TOpp_3rd_Down_Conv']/team['TOpp_3rd_Down_Att']
    team['TOpp_4th_Down%'] = team['TOpp_4th_Down_Conv']/team['TOpp_4th_Down_Att']
    team['Date'] = pd.to_datetime(team['Date'],errors='coerce',format='%Y-%m-%d')
    team['TGame_Dur'] = team['TGame_Dur']+':00'
    team['TO_ToP'] = '00:'+team['TO_ToP']
    team['TGame_Dur'] = pd.to_timedelta(team['TGame_Dur'],errors='coerce')
    team['TGame_Dur'] = team['TGame_Dur'].dt.total_seconds()
    team['TO_ToP'] = pd.to_timedelta(team['TO_ToP'],errors='coerce')
    team['TO_ToP'] = team['TO_ToP'].dt.total_seconds()
    team[team_cols[11:16]] = team[team_cols[11:16]].astype(float)
    team[team_cols[17]] = team[team_cols[17]].astype(float)
    team[team_cols[19:]] = team[team_cols[19:]].astype(float)
    team.insert(loc=9,column='Month',value=team['Date'].dt.month)
    
    
    
    injury = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nfl_injuryreport_{Start_Year}_{End_Year}.csv',low_memory=False)
    injury.drop('Unnamed: 0',axis=1,inplace=True)
    injury = pd.melt(injury,id_vars=['Player','Team','Year'],var_name='Date', value_name='Status')
    injury[['Date','Opp']] = injury.Date.str.split("vs. ",expand=True)
    injury[['Status','Injury']] = injury.Status.str.split(":",expand=True)
    injury['Date'] = injury['Date'].astype(str)+'/'+injury['Year'].astype(str)
    injury['Date'] = pd.to_datetime(injury['Date'])
    injury.replace({'Team':\
                       {'crd':'ARI', 'atl':'ATL', 'rav':'BAL', 'buf':'BUF', 'car':'CAR', 'chi':'CHI', 'cin':'CIN',\
                        'cle':'CLE', 'dal':'DAL', 'den':'DEN', 'det':'DET', 'gnb':'GNB','htx':'HOU','clt':'IND',\
                        'jax':'JAX','kan':'KAN','sdg':'LAC','ram':'LAR','mia':'MIA','min':'MIN','nor':'NOR','nwe':'NWE',\
                        'nyg':'NYG','nyj':'NYJ','rai':'OAK','phi':'PHI','pit':'PIT','sea':'SEA','sfo':'SFO','tam':'TAM',\
                        'oti':'TEN','was':'WAS'}},inplace=True)
    injury.dropna(axis=0,subset=['Status','Injury'],how='all',inplace=True)
    injury['Injury'] = injury['Injury'].str.strip(' ')
    injury.replace({'Injury':{'right':'','left':'','Right':'','Left':'','Biceps':'Bicep',\
                              'Triceps':'Tricep','Ankles':'Ankle','hip':'Hip','Hips':'Hip','Knees':'Knee',\
                              'Virus':'Illness','Triceps':'Tricep','Oblique':'Abdomen',\
                              'NotInjuryRelated':'Not Injury Related','MedicalIllness':'Illness',\
                              'LowerLeg':'Lower Leg','CoreMuscle':'Abdomen','Abdominal':'Abdomen'}},\
                               regex=True,inplace=True)
    injury['Player'] = injury['Player']+' '
    injury.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
    injury['Player'] = injury['Player'].str.strip(' ')


    stats_snaps = pd.merge(left=stats,right=snaps,how='outer',on=['Player','Year','Week'])
    stats_snaps['Team_x'] = stats_snaps['Team_x'].fillna(stats_snaps['Team_y'])
    stats_snaps['Pos_x'] = stats_snaps['Pos_y'].fillna(stats_snaps['Pos_x'])
    stats_snaps.drop(['Team_y','Pos_y'],axis=1,inplace=True)
    stats_snaps.rename(columns={'Team_x':'Team','Pos_x':'Pos'},inplace=True)

    stats_snaps_injury = pd.merge(left=stats_snaps,right=injury,how='outer',on=['Player','Year','Week'])
    
#     stats_snaps_injury = pd.merge
    
#     combined = pd.merge
    
#     combined.to_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nfl_total_{Start_Year}_{End_Year}.csv',index=False)
    
#     print("Done")

# %%
Start_Year = 2017
End_Year = 2019
Start = 2017
End = 2019

# %%
# reserve = injury['Status']=='reserve/future'
# injury_reserve = injury[reserve]
# injury_reserve.head()

# %%
# team_data_scrape(Start,End,1)

# %%
# player_snap_scrape(Start,End)

# %%
# injury_reports_scrape(Start,End)

# %%
# player_stats_scape(Start,End)

# %%
# data_clean(Start,End)

# %%
snaps = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\snapcounts_{Start_Year}_{End_Year}.csv')
snaps.drop(['Unnamed: 0','TTL','AVG'],axis=1,inplace=True)
snaps = pd.melt(snaps, id_vars=['Player','Pos','Team','Year'], var_name='Week', value_name='Snaps')
snaps['Year'] = snaps['Year'].astype(str)
snaps['Player'] = snaps['Player'].astype(str)
snaps['Week'] = snaps['Week'].astype(str)
snaps.replace({'Team':{'FA':'','GB':'GNB','JAC':'JAX','KC':'KAN','Multi':'','NE':'NWE','NO':'NOR','SF':'SFO','TB':'TAM'},\
                'Week':{'Week 1':'1','Week 2':'2','Week 3':'3','Week 4':'4','Week 5':'5','Week 6':'6',\
                        'Week 7':'7','Week 8':'8','Week 9':'9','Week 10':'10','Week 11':'11','Week 12':'12',\
                        'Week 13':'13','Week 14':'14','Week 15':'15','Week 16':'16','Week 17':'17'}},inplace=True)
snaps['Player'] = snaps['Player']+' '
snaps.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
snaps['Player'] = snaps['Player'].str.strip(' ')

for col in snaps.columns:
    print(col)

# %%
stats = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\player_stats_{Start_Year}_{End_Year}.csv')
stats.dropna(how='all',inplace=True)
stats.drop(stats[stats['Player'] == 'Player'].index, inplace = True)
stats.drop('Lg',axis=1,inplace=True)
stats.rename(columns={'Tm':'Team','Unnamed: 6':'Away_Home','Cmp':'IPass_Cmp','Att':'IPass_Att','Cmp%':'IPass_Cmp%','Yds':'IPass_Yds',\
             'TD':'IPass_TD','Int':'IPass_Int','Rate':'IQB_Rate','Sk':'I_Sk','Yds.1':'ISk_Yds','Y/A':'IPass_Y/A',\
             'AY/A':'IPass_AdjY/A','Att.1':'IRush_Att','Yds.2':'IRush_Yds','Y/A.1':'IRush_Y/A','TD.1':'IRush_TD',\
             'Tgt':'IRec_Tgt','Rec':'IRec_Rec','Yds.3':'IRec_Yds','Y/R':'IRec_Y/R','TD.2':'IRec_TD','Ctch%':'IRec_Ctch%',\
             'Y/Tgt':'IRec_Y/Tgt','XPM':'IXP_Made','XPA':'IXP_Att','XP%':'IXP%','FGM':'IFG_Made','FGA':'IFG_Att',\
             'FG%':'IFG%','2PM':'I2pt_Made','Sfty':'ISfty','TD.3':'ITot_TD','Pts':'ITot_Pts','Rt':'IKR_Rt','Yds.4':'IKR_Yds',\
             'Y/Rt':'IKR_Y/Rt','TD.4':'IKR_TD','Ret':'IPR_Rt','Yds.5':'IPR_Yds','Y/R.1':'IPR_Y/Rt','TD.5':'IPR_TD',\
             'Sk.1':'ITack_Sk','Solo':'ITack_Solo','Ast':'ITack_Ast','Comb':'ITack_Tot','TFL':'ITack_TFL',\
             'QBHits':'ITack_QBHits','Int.1':'IDef_Int','Yds.6':'IDef_IntYds','TD.6':'IDef_IntTD','PD':'IDef_PD',\
             'Fmb':'IFmb_Fmb','FL':'IFmb_Lost','FF':'IFmb_Forced','FR':'IFmb_Recov','Yds.7':'IFmb_Yds','TD.7':'IFmb_TD'},\
             inplace=True)

stats_cols = []
for col in stats.columns:
    stats_cols.append(col)

stats.replace({'Away_Home':{'@':'Away',None:'Home'}},inplace=True)
stats[['IPass_Cmp','IPass_Att','IRec_Rec','IRec_Tgt','IXP_Made','IXP_Att','IFG_Made','IFG_Att']] = stats[['IPass_Cmp','IPass_Att','IRec_Rec','IRec_Tgt','IXP_Made','IXP_Att','IFG_Made','IFG_Att']].astype(float)
stats['IPass_Cmp%'] = stats['IPass_Cmp']/stats['IPass_Att']
stats['IRec_Ctch%'] = stats['IRec_Rec']/stats['IRec_Tgt']
stats['IXP%'] = stats['IXP_Made']/stats['IXP_Att']
stats['IFG%'] = stats['IFG_Made']/stats['IFG_Att']
stats[stats_cols[11:]] = stats[stats_cols[11:]].astype(float)
stats[stats_cols[11:]] = stats[stats_cols[11:]].fillna(value=0)
stats['Date'] = pd.to_datetime(stats['Date'],errors='coerce',format='%Y-%m-%d')
stats.insert(loc=8,column='Year',value=stats['Date'].dt.year)
stats['Player'] = stats['Player'].astype(str)
stats['Week'] = stats['Week'].astype(str)
stats['Year'] = stats['Year'].astype(str)
stats['Player'] = stats['Player']+' '
stats.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
stats['Player'] = stats['Player'].str.strip(' ')

for col in stats.columns:
    print(col)

# %%
team1 = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_1_{Start_Year}_{End_Year}.csv')
team2 = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nflteam_data_2_{Start_Year}_{End_Year}.csv')
team1.dropna(thresh=10,inplace=True)
team2.dropna(thresh=10,inplace=True)
team1.drop('LTime',axis=1,inplace=True)
team2.drop(['LTime'],axis=1,inplace=True)
test1 = team1.columns
test2 = team2.columns
team1.rename(columns={'Tm':'Team','Unnamed: 5':'Away_Home','PF':'Points_For','PA':'Points_Against','PC':'Points_Comb',\
                     'vs. Line':'Vs_Line','Cmp':'TPass_Cmp','Att':'TPass_Att','Cmp%':'TPass_Cmp%','Yds':'TPass_Yds',\
                      'TD':'TPass_TD','Int':'TPass_Int','Sk':'TSack','Yds.1':'TSack_Yds','Rate':'TQB_Rate',\
                      'Att.1':'TRush_Att','Yds.2':'TRush_Yds','Y/A':'TRush_Y/A','TD.1':'TRush_TD','Tot':'TTot_Yds',\
                      'Ply':'TO_Play#','Y/P':'TO_Y/P','DPly':'TD_Play#','DY/P':'TD_Y/P','TO':'TTot_TO','ToP':'TO_ToP',\
                      'Time.1':'TGame_Dur','Yds.3':'TPen_Yds','OppPen':'TOpp_Pen','OppYds':'TOpp_Pen_Yds',\
                      'CombPen':'TComb_Pen','CombPenYds':'TComb_Pen_Yds','1stD':'T1st_Downs','Rsh':'T1st_by_Rsh',\
                      'Pass':'T1st_by_Pass','Pen.1':'T1st_by_Pen','3DAtt':'T3rd_Down_Att','3DConv':'T3rd_Down_Conv',\
                      '3D%':'T3rd_Down%','4DAtt':'T4th_Down_Att','4DConv':'T4th_Down_Conv','4D%':'T4th_Down%',\
                      'TD.2':'TTot_TD','XPA':'TXP_Att','XPM':'TXP_Made','FGA':'TFG_Att','FGM':'TFG_Made','2PA':'T2Pt_Att',\
                      '2PM':'T2Pt_Made','Sfty':'TSfty','Pnt':'TTimes_Punted','Yds.4':'TPunt_Yds','Y/P.1':'TPunt_Yds_Avg'},inplace=True)
team2.rename(columns={'Tm':'Team','Unnamed: 5':'Away_Home','TD':'TOpp_Tot_TD','XPA':'TOpp_XP_Att','XPM':'TOpp_XP_Made',\
                      'Att':'TOpp_FG_Att','Md':'TOpp_FG_Made','Sfty':'TOpp_Sfty','Cmp':'TOpp_Pass_Cmp','Att.1':'TOpp_Pass_Att',\
                      'Cmp%':'TOpp_Pass_Cmp%','Yds':'TOpp_Pass_Yds','TD.1':'TOpp_Pass_TD','Int':'TOpp_Pass_Int','Sk':'TOpp_Sk',\
                      'Yds.1':'TOpp_Sk_Yds','Rate':'TOpp_QB_Rate','Att.2':'TOpp_Rush_Att','Yds.2':'TOpp_Rush_Yds',\
                      'Y/A':'TOpp_Rush_Y/A','TD.2':'TOpp_Rush_TD','Tot':'TOpp_Tot_Yds','TO':'TOpp_Tot_TO',\
                      '1stDOpp':'TOpp_1st_Downs','Rush':'TOpp_1st_by_Rsh','Pass':'TOpp_1st_by_Pass','Pen':'TOpp_1st_by_Pen',\
                      'Opp3DAtt':'TOpp_3rd_Down_Att','Opp3DConv':'TOpp_3rd_Down_Conv','Opp3D%':'TOpp_3rd_Down%',\
                      'Opp4DAtt':'TOpp_4th_Down_Att','Opp4DConv':'TOpp_4th_Down_Conv','Opp4D%':'TOpp_4th_Down%',\
                      'Rush.1':'TMargin_Rush','Pass.1':'TMargin_Pass','Tot.1':'TMargin_TotYds','TO.1':'TTO_TD',\
                      'KR':'TKR_TD','PR':'TPR_TD','IR':'TInt_TD','FR':'TFmb_TD','OR':'TOtherRet_TD',\
                      'RetTD':'TAll_Ret_TD','Q1':'TMar_Thru_Q1','Q2':'TMar_Thru_Q2','Q3':'TMar_Thru_Q3',\
                      'Q1.1':'TScore_Diff_Q1','Q2.1':'TScore_Diff_Q2','Q3.1':'TScore_Diff_Q3',\
                      'Q4':'TScore_Diff_Q4','1stHalf':'TScore_Diff_1stHalf','2ndHalf':'TScore_Diff_2ndHalf'},inplace=True)

team = pd.merge(left=team1,right=team2,\
                 how='outer',\
                 on=['Team','Year','Date','Time','Away_Home','Opp','Week','G#','Day','Result','OT'])

team.set_index('Team',inplace=True)
team.drop('Tm',inplace=True)
team.reset_index(inplace=True)

team_cols = []

for col in team.columns:
    team_cols.append(col)

team.replace({'Away_Home':{'@':'Away',None:'Home'}},inplace=True)
team[team_cols[11:]] = team[team_cols[11:]].fillna(value=0)
team[['TPass_Cmp','TPass_Att','T3rd_Down_Att','T3rd_Down_Conv','T4th_Down_Att',\
      'T4th_Down_Conv','TOpp_Pass_Cmp','TOpp_Pass_Att','TOpp_3rd_Down_Att',\
      'TOpp_3rd_Down_Conv','TOpp_4th_Down_Att','TOpp_4th_Down_Conv']] = team[['TPass_Cmp','TPass_Att','T3rd_Down_Att',\
                                                                              'T3rd_Down_Conv','T4th_Down_Att',\
                                                                              'T4th_Down_Conv','TOpp_Pass_Cmp',\
                                                                              'TOpp_Pass_Att','TOpp_3rd_Down_Att',\
                                                                              'TOpp_3rd_Down_Conv','TOpp_4th_Down_Att',\
                                                                              'TOpp_4th_Down_Conv']].astype(float)
team['TPass_Cmp%'] = team['TPass_Cmp']/team['TPass_Att']
team['T3rd_Down%'] = team['T3rd_Down_Conv']/team['T3rd_Down_Att']
team['T4th_Down%'] = team['T4th_Down_Conv']/team['T4th_Down_Att']
team['TOpp_Pass_Cmp%'] = team['TOpp_Pass_Cmp']/team['TOpp_Pass_Att']
team['TOpp_3rd_Down%'] = team['TOpp_3rd_Down_Conv']/team['TOpp_3rd_Down_Att']
team['TOpp_4th_Down%'] = team['TOpp_4th_Down_Conv']/team['TOpp_4th_Down_Att']
team['Date'] = pd.to_datetime(team['Date'],errors='coerce',format='%Y-%m-%d')
team['TGame_Dur'] = team['TGame_Dur']+':00'
team['TO_ToP'] = '00:'+team['TO_ToP']
team['TGame_Dur'] = pd.to_timedelta(team['TGame_Dur'],errors='coerce')
team['TGame_Dur'] = team['TGame_Dur'].dt.total_seconds()
team['TO_ToP'] = pd.to_timedelta(team['TO_ToP'],errors='coerce')
team['TO_ToP'] = team['TO_ToP'].dt.total_seconds()
team[team_cols[11:16]] = team[team_cols[11:16]].astype(float)
team[team_cols[17]] = team[team_cols[17]].astype(float)
team[team_cols[19:]] = team[team_cols[19:]].astype(float)
team.insert(loc=9,column='Month',value=team['Date'].dt.month)


for col in team.columns:
    print(col)

# %%
injury = pd.read_csv(rf'C:\Users\cudde\OneDrive\Podcasting\Fantasy Sidelines\Injury Data Python\Data_Collect_Clean\nfl_data\nfl_injuryreport_{Start_Year}_{End_Year}.csv',low_memory=False)
injury.drop('Unnamed: 0',axis=1,inplace=True)
injury = pd.melt(injury,id_vars=['Player','Team','Year'],var_name='Date', value_name='Status')
injury[['Date','Opp']] = injury.Date.str.split('vs. ',expand=True)
injury[['Month','Day']] = injury.Date.str.split('/',expand=True)
injury[['Status','Injury']] = injury.Status.str.split(":",expand=True)
injury.dropna(axis=0,subset=['Status','Injury'],how='all',inplace=True)
injury[['Year','Month','Day']] = injury[['Year','Month','Day']].astype(int)
injury['Date'] = injury['Date']+'/'+(np.where(injury['Month']<=2,injury['Year']+1,injury['Year'])).astype(str)
injury['Date'] = pd.to_datetime(injury['Date'])
past_week17 = injury[(injury['Month']==1)&(injury['Day']>=4)].index
playoffs = injury[(injury['Month']==2)].index
injury.drop(past_week17,inplace = True)
injury.drop(playoffs,inplace=True)
injury.replace({'Team':\
                   {'crd':'ARI', 'atl':'ATL', 'rav':'BAL', 'buf':'BUF', 'car':'CAR', 'chi':'CHI', 'cin':'CIN',\
                    'cle':'CLE', 'dal':'DAL', 'den':'DEN', 'det':'DET', 'gnb':'GNB','htx':'HOU','clt':'IND',\
                    'jax':'JAX','kan':'KAN','sdg':'LAC','ram':'LAR','mia':'MIA','min':'MIN','nor':'NOR','nwe':'NWE',\
                    'nyg':'NYG','nyj':'NYJ','rai':'OAK','phi':'PHI','pit':'PIT','sea':'SEA','sfo':'SFO','tam':'TAM',\
                    'oti':'TEN','was':'WAS'}},inplace=True)
injury['Injury'] = injury['Injury'].str.strip(' ')
injury.replace({'Injury':{'right':'','left':'','Right':'','Left':'','Biceps':'Bicep',\
                          'Triceps':'Tricep','Ankles':'Ankle','hip':'Hip','Hips':'Hip','Knees':'Knee',\
                          'Virus':'Illness','Triceps':'Tricep','Oblique':'Abdomen',\
                          'NotInjuryRelated':'Not Injury Related','MedicalIllness':'Illness',\
                          'LowerLeg':'Lower Leg','CoreMuscle':'Abdomen','Abdominal':'Abdomen'}},\
                           regex=True,inplace=True)
injury['Player'] = injury['Player']+' '
injury.replace({'Player':{' Jr. ':'',' Jr ':'',' Sr. ':'',' Sr ':'',' III ':'',' II ':'',' IV ':'',' V ':''}},regex=True,inplace=True)
injury['Player'] = injury['Player'].str.strip(' ')
injury.sort_values(by=['Month','Day'],ascending=[True,False]).head(1500)
# for col in injury.columns:
#     print(col)
# Out:
#                               Player Team  Year       Date  \
# 2063939              Bryson Albright  ARI  2018 2018-09-30
# 2063946           Christian Campbell  ARI  2018 2018-09-30
# 2063947                  Jeremy Cash  ARI  2018 2018-09-30
# 2063951             Larry Fitzgerald  ARI  2018 2018-09-30
# 2063952                  D.J. Foster  ARI  2018 2018-09-30
# 2063962                  Gabe Martin  ARI  2018 2018-09-30
# 2063963         Praise Martin-Oguike  ARI  2018 2018-09-30
# 2063965                 Arthur Moats  ARI  2018 2018-09-30
# 2063967             Robert Nkemdiche  ARI  2018 2018-09-30
# 2063968               Jonathan Owens  ARI  2018 2018-09-30
# 2063969                 Corey Peters  ARI  2018 2018-09-30
# 2063972                 Olsen Pierre  ARI  2018 2018-09-30
# 2063976                 A.Q. Shipley  ARI  2018 2018-09-30
# 2063977                  Andre Smith  ARI  2018 2018-09-30
# 2125439                Ricardo Allen  ATL  2018 2018-09-30
# 2125440                Justin Bethel  ATL  2018 2018-09-30
# 2125442              Devonta Freeman  ATL  2018 2018-09-30
# 2125448                  Deion Jones  ATL  2018 2018-09-30
# 2125450                 Andy Levitre  ATL  2018 2018-09-30
# 2125453                   Keanu Neal  ATL  2018 2018-09-30
# 2125457               Derrick Shelby  ATL  2018 2018-09-30
# 2127680            Anthony Chickillo  PIT  2019 2019-09-30
# 2127682                   Sean Davis  PIT  2019 2019-09-30
# 2127683              Jayrone Elliott  PIT  2019 2019-09-30
# 2127686               Xavier Grimble  PIT  2019 2019-09-30
# 2127688                  Lavon Hooks  PIT  2019 2019-09-30
# 2127689               Vance McDonald  PIT  2019 2019-09-30
# 2127691                Roosevelt Nix  PIT  2019 2019-09-30
# 2127693           Ben Roethlisberger  PIT  2019 2019-09-30
# 2127696                 Ryan Shazier  PIT  2019 2019-09-30
# 2127703               Vince Williams  PIT  2019 2019-09-30
# 2183075             Quincy Adeboyejo  BAL  2018 2018-09-30
# 2183076              Anthony Averett  BAL  2018 2018-09-30
# 2183079                  Bam Bradley  BAL  2018 2018-09-30
# 2183081               Maurice Canady  BAL  2018 2018-09-30
# 2183082                 Brandon Carr  BAL  2018 2018-09-30
# 2183084                Kenneth Dixon  BAL  2018 2018-09-30
# 2183086               DeShon Elliott  BAL  2018 2018-09-30
# 2183089                 Willie Henry  BAL  2018 2018-09-30
# 2183090                  Jaylen Hill  BAL  2018 2018-09-30
# 2183092                 Hayden Hurst  BAL  2018 2018-09-30
# 2183094              Bennett Jackson  BAL  2018 2018-09-30
# 2183095        Stanley Jean-Baptiste  BAL  2018 2018-09-30
# 2183099               Anthony Levine  BAL  2018 2018-09-30
# 2183101                 Steven Moore  BAL  2018 2018-09-30
# 2183102                  C.J. Mosley  BAL  2018 2018-09-30
# 2183103               Michael Pierce  BAL  2018 2018-09-30
# 2183104                 Jaleel Scott  BAL  2018 2018-09-30
# 2183105                   Greg Senat  BAL  2018 2018-09-30
# 2183108               Ronnie Stanley  BAL  2018 2018-09-30
# 2183109                Terrell Suggs  BAL  2018 2018-09-30
# 2183110                Alex Thompson  BAL  2018 2018-09-30
# 2183112                 Kaare Vedvik  BAL  2018 2018-09-30
# 2184461              Rodney Anderson  CIN  2019 2019-09-30
# 2184464             Darqueze Dennard  CIN  2019 2019-09-30
# 2184466                 O'Shea Dugas  CIN  2019 2019-09-30
# 2184469                 Ryan Glasgow  CIN  2019 2019-09-30
# 2184470                  Cordy Glenn  CIN  2019 2019-09-30
# 2184471                   A.J. Green  CIN  2019 2019-09-30
# 2184477                  Carl Lawson  CIN  2019 2019-09-30
# 2184481              Darius Phillips  CIN  2019 2019-09-30
# 2184485                  Niles Scott  CIN  2019 2019-09-30
# 2184490               Jonah Williams  CIN  2019 2019-09-30
# 2184495                   Kerry Wynn  CIN  2019 2019-09-30
# 2248418                  Cory Carter  BUF  2018 2018-09-30
# 2248419                 Charles Clay  BUF  2018 2018-09-30
# 2248420                  Jason Croom  BUF  2018 2018-09-30
# 2248422                  Aaron Green  BUF  2018 2018-09-30
# 2248432                 LeSean McCoy  BUF  2018 2018-09-30
# 2248436                Marcus Murphy  BUF  2018 2018-09-30
# 2356027             Prince Amukamara  CHI  2018 2018-09-30
# 2356030                 Marlon Brown  CHI  2018 2018-09-30
# 2356033                Marcus Cooper  CHI  2018 2018-09-30
# 2356043               Anthony Miller  CHI  2018 2018-09-30
# 2356044                  Zach Miller  CHI  2018 2018-09-30
# 2356047                 Adam Shaheen  CHI  2018 2018-09-30
# 2356050             Andrew Trumbetti  CHI  2018 2018-09-30
# 2421349                 Matt Barkley  CIN  2018 2018-09-30
# 2421350                 Brandon Bell  CIN  2018 2018-09-30
# 2421354              Vontaze Burfict  CIN  2018 2018-09-30
# 2421355                   Tra Carson  CIN  2018 2018-09-30
# 2421356                Cethan Carter  CIN  2018 2018-09-30
# 2421363                 Ryan Glasgow  CIN  2018 2018-09-30
# 2421366              Davontae Harris  CIN  2018 2018-09-30
# 2421367            Trayvon Henderson  CIN  2018 2018-09-30
# 2421375              Javarius Leamon  CIN  2018 2018-09-30
# 2421378                    Joe Mixon  CIN  2018 2018-09-30
# 2421380                  Billy Price  CIN  2018 2018-09-30
# 2421385                   Rod Taylor  CIN  2018 2018-09-30
# 2482847                   C.J. Board  CLE  2018 2018-09-30
# 2482849                James Burgess  CLE  2018 2018-09-30
# 2482853                Justin Currie  CLE  2018 2018-09-30
# 2482854                 Seth Devalve  CLE  2018 2018-09-30
# 2482860                  Lenny Jones  CLE  2018 2018-09-30
# 2482863                Ricardo Louis  CLE  2018 2018-09-30
# 2482868            Damarious Randall  CLE  2018 2018-09-30
# 2482872                 Tyrod Taylor  CLE  2018 2018-09-30
# 2482877                 Danny Vitale  CLE  2018 2018-09-30
# 2482879             Marquez Williams  CLE  2018 2018-09-30
# 2482881                Howard Wilson  CLE  2018 2018-09-30
# 2544340                 Cole Beasley  DAL  2018 2018-09-30
# 2544342                   Noah Brown  DAL  2018 2018-09-30
# 2544344               Maliek Collins  DAL  2018 2018-09-30
# 2544346               Parker Ehinger  DAL  2018 2018-09-30
# 2544348             Travis Frederick  DAL  2018 2018-09-30
# 2544355                 Datone Jones  DAL  2018 2018-09-30
# 2544357                     Sean Lee  DAL  2018 2018-09-30
# 2544359                Marcus Martin  DAL  2018 2018-09-30
# 2544363              Jameill Showers  DAL  2018 2018-09-30
# 2544372               Cedrick Wilson  DAL  2018 2018-09-30
# 2544373                Antwaun Woods  DAL  2018 2018-09-30
# 2667326                Ezekiel Ansah  DET  2018 2018-09-30
# 2667327               Brandon Barnes  DET  2018 2018-09-30
# 2667329                  Nick Bawden  DET  2018 2018-09-30
# 2667333             Marcus Cromartie  DET  2018 2018-09-30
# 2667334                 Jarrad Davis  DET  2018 2018-09-30
# 2667345                   Andy Jones  DET  2018 2018-09-30
# 2667350                  Steve Longa  DET  2018 2018-09-30
# 2667354              Michael Roberts  DET  2018 2018-09-30
# 2667359                  Golden Tate  DET  2018 2018-09-30
# 2667363         Cornelius Washington  DET  2018 2018-09-30
# 2667366                  Zach Zenner  DET  2018 2018-09-30
# 2724996                Michael Clark  GNB  2018 2018-09-30
# 2724997                 Randall Cobb  GNB  2018 2018-09-30
# 2725000                 Trevor Davis  GNB  2018 2018-09-30
# 2725003                  Davon House  GNB  2018 2018-09-30
# 2725005                   Josh Jones  GNB  2018 2018-09-30
# 2725006                   Kevin King  GNB  2018 2018-09-30
# 2725007                 Jake Kumerow  GNB  2018 2018-09-30
# 2725008                 Cole Madison  GNB  2018 2018-09-30
# 2725010                Justin McCray  GNB  2018 2018-09-30
# 2725011                  Kyle Murphy  GNB  2018 2018-09-30
# 2725013                   Nick Perry  GNB  2018 2018-09-30
# 2725015                Aaron Rodgers  GNB  2018 2018-09-30
# 2725016                    Jake Ryan  GNB  2018 2018-09-30
# 2725020           Muhammad Wilkerson  GNB  2018 2018-09-30
# 2778799                   Dylan Cole  HOU  2018 2018-09-30
# 2778806              Bruce Ellington  HOU  2018 2018-09-30
# 2778807               D'Onta Foreman  HOU  2018 2018-09-30
# 2778810                Matthew Godin  HOU  2018 2018-09-30
# 2778812                    Andre Hal  HOU  2018 2018-09-30
# 2778813                   Ben Heeney  HOU  2018 2018-09-30
# 2778814           Seantrel Henderson  HOU  2018 2018-09-30
# 2778815              DeAndre Hopkins  HOU  2018 2018-09-30
# 2778816                Kevin Johnson  HOU  2018 2018-09-30
# 2778819               Jermaine Kelly  HOU  2018 2018-09-30
# 2778822              Jevoni Robinson  HOU  2018 2018-09-30
# 2778828               Kayvon Webster  HOU  2018 2018-09-30
# 2778829              Shareece Wright  HOU  2018 2018-09-30
# 2840288                    Deon Cain  IND  2018 2018-09-30
# 2840289             Johnathan Calvin  IND  2018 2018-09-30
# 2840290             Anthony Castonzo  IND  2018 2018-09-30
# 2840291                 Chris Cooper  IND  2018 2018-09-30
# 2840292                   Jack Doyle  IND  2018 2018-09-30
# 2840295                Josh Ferguson  IND  2018 2018-09-30
# 2840297             Clayton Geathers  IND  2018 2018-09-30
# 2840298              Jeremiah George  IND  2018 2018-09-30
# 2840302                     Joe Haeg  IND  2018 2018-09-30
# 2840304                   Matt Hazel  IND  2018 2018-09-30
# 2840308                Austin Howard  IND  2018 2018-09-30
# 2840311               Robert Jackson  IND  2018 2018-09-30
# 2840312              Anthony Johnson  IND  2018 2018-09-30
# 2840314                   Brad Kaaya  IND  2018 2018-09-30
# 2840318                 Tyquan Lewis  IND  2018 2018-09-30
# 2840319              Kolby Listenbee  IND  2018 2018-09-30
# 2840320                  Marlon Mack  IND  2018 2018-09-30
# 2840321                Ronald Martin  IND  2018 2018-09-30
# 2840323                 Chris McCain  IND  2018 2018-09-30
# 2840331              Hassan Ridgeway  IND  2018 2018-09-30
# 2840337            Robenson Therezie  IND  2018 2018-09-30
# 2840338                  Ross Travis  IND  2018 2018-09-30
# 2840342             Jeremy Vujnovich  IND  2018 2018-09-30
# 2840343               Anthony Walker  IND  2018 2018-09-30
# 2840345                J'Marcus Webb  IND  2018 2018-09-30
# 2840346                Quincy Wilson  IND  2018 2018-09-30
# 2840348                 James Wright  IND  2018 2018-09-30
# 2909487                Kenneth Acker  JAX  2018 2018-09-30
# 2909491                    A.J. Cann  JAX  2018 2018-09-30
# 2909492                    Don Carey  JAX  2018 2018-09-30
# 2909494                  Zach Conque  JAX  2018 2018-09-30
# 2909497                  Kaleb Eulls  JAX  2018 2018-09-30
# 2909498            Leonard Fournette  JAX  2018 2018-09-30
# 2909500              DeAndre Goolsby  JAX  2018 2018-09-30
# 2909502               David Grinnage  JAX  2018 2018-09-30
# 2909504                  D.J. Hayden  JAX  2018 2018-09-30
# 2909505               Michael Hughes  JAX  2018 2018-09-30
# 2909510                  Marqise Lee  JAX  2018 2018-09-30
# 2909511           Kapron Lewis-Moore  JAX  2018 2018-09-30
# 2909524                 Cam Robinson  JAX  2018 2018-09-30
# 2909527                 Tevaun Smith  JAX  2018 2018-09-30
# 2909528               Brandon Thomas  JAX  2018 2018-09-30
# 3032476                 Keenan Allen  LAC  2018 2018-09-30
# 3032477                Joe Barksdale  LAC  2018 2018-09-30
# 3032478              Travis Benjamin  LAC  2018 2018-09-30
# 3032479                    Joey Bosa  LAC  2018 2018-09-30
# 3032480                  Brett Boyko  LAC  2018 2018-09-30
# 3032488                 Hunter Henry  LAC  2018 2018-09-30
# 3032491                  Craig Mager  LAC  2018 2018-09-30
# 3032496               Austin Roberts  LAC  2018 2018-09-30
# 3032497                Artavis Scott  LAC  2018 2018-09-30
# 3032499                Jason Verrett  LAC  2018 2018-09-30
# 3032500               Jaylen Watkins  LAC  2018 2018-09-30
# 3032502                  Kyzir White  LAC  2018 2018-09-30
# 3163124                  Chase Allen  MIA  2018 2018-09-30
# 3163129                 Andre Branch  MIA  2018 2018-09-30
# 3163130                 Jake Brendel  MIA  2018 2018-09-30
# 3163132                   A.J. Derby  MIA  2018 2018-09-30
# 3163135               Davon Godchaux  MIA  2018 2018-09-30
# 3163138                MarQueis Gray  MIA  2018 2018-09-30
# 3163140                William Hayes  MIA  2018 2018-09-30
# 3163143                    Mike Hull  MIA  2018 2018-09-30
# 3163145                 Reshad Jones  MIA  2018 2018-09-30
# 3163152               DeVante Parker  MIA  2018 2018-09-30
# 3163153                  Josh Sitton  MIA  2018 2018-09-30
# 3163160                 Cameron Wake  MIA  2018 2018-09-30
# 3163163                    Sam Young  MIA  2018 2018-09-30
# 3282276              Brandon Coleman  NOR  2018 2018-09-30
# 3282277             Marcus Davenport  NOR  2018 2018-09-30
# 3282279                 Travin Dural  NOR  2018 2018-09-30
# 3282280              John Fullington  NOR  2018 2018-09-30
# 3282282         Michael Hoomanawanui  NOR  2018 2018-09-30
# 3282283             Rickey Jefferson  NOR  2018 2018-09-30
# 3282285                 Daniel Lasco  NOR  2018 2018-09-30
# 3282287               Tommylee Lewis  NOR  2018 2018-09-30
# 3282293             Patrick Robinson  NOR  2018 2018-09-30
# 3282296                   Manti Te'o  NOR  2018 2018-09-30
# 3282297                   John Theus  NOR  2018 2018-09-30
# 3282299                 Shane Vereen  NOR  2018 2018-09-30
# 3343759               Darren Andrews  NWE  2018 2018-09-30
# 3343760             Ja'Whaun Bentley  NWE  2018 2018-09-30
# 3343761              Braxton Berrios  NWE  2018 2018-09-30
# 3343764                  Kenny Britt  NWE  2018 2018-09-30
# 3343767                 Rex Burkhead  NWE  2018 2018-09-30
# 3343769                Marcus Cannon  NWE  2018 2018-09-30
# 3343771                Patrick Chung  NWE  2018 2018-09-30
# 3343772                Keion Crossen  NWE  2018 2018-09-30
# 3343773                  Duke Dawson  NWE  2018 2018-09-30
# 3343774                   Nate Ebner  NWE  2018 2018-09-30
# 3343776                 Trey Flowers  NWE  2018 2018-09-30
# 3343778                  Josh Gordon  NWE  2018 2018-09-30
# 3343780                Geneo Grissom  NWE  2018 2018-09-30
# 3343781               Rob Gronkowski  NWE  2018 2018-09-30
# 3343783                  Jeremy Hill  NWE  2018 2018-09-30
# 3343785              Jacob Hollister  NWE  2018 2018-09-30
# 3343786                    Ryan Izzo  NWE  2018 2018-09-30
# 3343787                  Ulrick John  NWE  2018 2018-09-30
# 3343789                 Brandon King  NWE  2018 2018-09-30
# 3343795                    Eric Rowe  NWE  2018 2018-09-30
# 3343796                Christian Sam  NWE  2018 2018-09-30
# 3343801                 Nate Theaker  NWE  2018 2018-09-30
# 3343804                  Isaiah Wynn  NWE  2018 2018-09-30
# 3412943                    Eli Apple  NYG  2018 2018-09-30
# 3412944          Thurston Armbrister  NYG  2018 2018-09-30
# 3412946                     Sam Beal  NYG  2018 2018-09-30
# 3412948                  Nick Becton  NYG  2018 2018-09-30
# 3412950                  Kaelin Clay  NYG  2018 2018-09-30
# 3412951                  Stacy Coley  NYG  2018 2018-09-30
# 3412956                  Evan Engram  NYG  2018 2018-09-30
# 3412957                   Nick Gates  NYG  2018 2018-09-30
# 3412959                  Jon Halapio  NYG  2018 2018-09-30
# 3412960             Antonio Hamilton  NYG  2018 2018-09-30
# 3412962                 Cody Latimer  NYG  2018 2018-09-30
# 3412963                R.J. McIntosh  NYG  2018 2018-09-30
# 3412966                 Paul Perkins  NYG  2018 2018-09-30
# 3412969              Kristjan Sokoli  NYG  2018 2018-09-30
# 3412970             Jonathan Stewart  NYG  2018 2018-09-30
# 3412971               Olivier Vernon  NYG  2018 2018-09-30
# 3412972              Jordan Williams  NYG  2018 2018-09-30
# 3459076                  Ben Ijalana  NYJ  2018 2018-09-30
# 3459085                  Marcus Maye  NYJ  2018 2018-09-30
# 3459086               Elijah McGuire  NYJ  2018 2018-09-30
# 3459088               Doug Middleton  NYJ  2018 2018-09-30
# 3459089                 Rontez Miles  NYJ  2018 2018-09-30
# 3459090                Charone Peake  NYJ  2018 2018-09-30
# 3459091                 Claude Pelon  NYJ  2018 2018-09-30
# 3459098                Buster Skrine  NYJ  2018 2018-09-30
# 3459099                Neal Sterling  NYJ  2018 2018-09-30
# 3512879               Andrew DePaola  OAK  2018 2018-09-30
# 3512880                 Justin Ellis  OAK  2018 2018-09-30
# 3512883                    P.J. Hall  OAK  2018 2018-09-30
# 3512887                  Karl Joseph  OAK  2018 2018-09-30
# 3512893              Dexter McDonald  OAK  2018 2018-09-30
# 3512895                Obi Melifonwu  OAK  2018 2018-09-30
# 3512896                Tevin Mitchel  OAK  2018 2018-09-30
# 3512900                  Mike Nugent  OAK  2018 2018-09-30
# 3512903                 Eddy Pineiro  OAK  2018 2018-09-30
# 3512905         Shaquille Richardson  OAK  2018 2018-09-30
# 3512907  Dominique Rodgers-Cromartie  OAK  2018 2018-09-30
# 3512908                 Ahtyba Rubin  OAK  2018 2018-09-30
# 3512911             Eddie Vanderdoes  OAK  2018 2018-09-30
# 3512912                 Chris Warren  OAK  2018 2018-09-30
# 3512914                 Griff Whalen  OAK  2018 2018-09-30
# 3570537                   Elie Bouka  PHI  2018 2018-09-30
# 3570538                Corey Clement  PHI  2018 2018-09-30
# 3570545                 Mack Hollins  PHI  2018 2018-09-30
# 3570546               Alshon Jeffery  PHI  2018 2018-09-30
# 3570547               Timmy Jernigan  PHI  2018 2018-09-30
# 3570554                Chris Maragos  PHI  2018 2018-09-30
# 3570555                Rodney McLeod  PHI  2018 2018-09-30
# 3570560              Richard Rodgers  PHI  2018 2018-09-30
# 3570562               Darren Sproles  PHI  2018 2018-09-30
# 3570564                 Bryce Treggs  PHI  2018 2018-09-30
# 3570566                 Mike Wallace  PHI  2018 2018-09-30
# 3570567              Toby Weathersby  PHI  2018 2018-09-30
# 3570569                Paul Worrilow  PHI  2018 2018-09-30
# 3570570                  Adam Zaruba  PHI  2018 2018-09-30
# 3635868          Olasunkanmi Adeniyi  PIT  2018 2018-09-30
# 3635873               Morgan Burnett  PIT  2018 2018-09-30
# 3635875                    Joe Cheek  PIT  2018 2018-09-30
# 3635885               Jerald Hawkins  PIT  2018 2018-09-30
# 3635888                  Mike Hilton  PIT  2018 2018-09-30
# 3635890                 Trey Johnson  PIT  2018 2018-09-30
# 3635891                 Keith Kelsey  PIT  2018 2018-09-30
# 3635892                 Ryan Malleck  PIT  2018 2018-09-30
# 3635895                   Jake McGee  PIT  2018 2018-09-30
# 3635897                   Eli Rogers  PIT  2018 2018-09-30
# 3635899                 Ryan Shazier  PIT  2018 2018-09-30
# 3693521               Ricky Ali'ifua  SEA  2018 2018-09-30
# 3693522                 Doug Baldwin  SEA  2018 2018-09-30
# 3693523                Emmanuel Beal  SEA  2018 2018-09-30
# 3693525                 Chris Carson  SEA  2018 2018-09-30
# 3693526               Kam Chancellor  SEA  2018 2018-09-30
# 3693528                 Amara Darboh  SEA  2018 2018-09-30
# 3693529                 Austin Davis  SEA  2018 2018-09-30
# 3693530                   Ed Dickson  SEA  2018 2018-09-30
# 3693534               Jermaine Grace  SEA  2018 2018-09-30
# 3693535                Rasheem Green  SEA  2018 2018-09-30
# 3693538                  Khalid Hill  SEA  2018 2018-09-30
# 3693539                    Lano Hill  SEA  2018 2018-09-30
# 3693541               Dontae Johnson  SEA  2018 2018-09-30
# 3693542                Jamarco Jones  SEA  2018 2018-09-30
# 3693544                  Dion Jordan  SEA  2018 2018-09-30
# 3693548                Byron Maxwell  SEA  2018 2018-09-30
# 3693550               Malik McDowell  SEA  2018 2018-09-30
# 3693551                J.D. McKissic  SEA  2018 2018-09-30
# 3693552              T.J. Mutcherson  SEA  2018 2018-09-30
# 3693555                  Ethan Pocic  SEA  2018 2018-09-30
# 3693556                 C.J. Prosise  SEA  2018 2018-09-30
# 3693566                  Erik Walden  SEA  2018 2018-09-30
# 3693567                  K.J. Wright  SEA  2018 2018-09-30
# 3755025                  Matt Breida  SFO  2018 2018-09-30
# 3755026              Aaron Burbridge  SFO  2018 2018-09-30
# 3755028               Adrian Colbert  SFO  2018 2018-09-30
# 3755029              Jonathan Cooper  SFO  2018 2018-09-30
# 3755030                  Brock Coyle  SFO  2018 2018-09-30
# 3755031                  Antone Exum  SFO  2018 2018-09-30
# 3755032                     JP Flynn  SFO  2018 2018-09-30
# 3755035               Joshua Garnett  SFO  2018 2018-09-30
# 3755036              Jimmy Garoppolo  SFO  2018 2018-09-30
# 3755038               Marcell Harris  SFO  2018 2018-09-30
# 3755043              Jerick McKinnon  SFO  2018 2018-09-30
# 3755045                Alfred Morris  SFO  2018 2018-09-30
# 3755053              Richard Sherman  SFO  2018 2018-09-30
# 3755056             Kentavius Street  SFO  2018 2018-09-30
# 3755057               Jaquiski Tartt  SFO  2018 2018-09-30
# 3755060                Dekoda Watson  SFO  2018 2018-09-30
# 3804997                   Beau Allen  TAM  2018 2018-09-30
# 3804998                Sergio Bailey  TAM  2018 2018-09-30
# 3804999               Tavaris Barnes  TAM  2018 2018-09-30
# 3805000             Kendell Beckwith  TAM  2018 2018-09-30
# 3805001                 Devante Bond  TAM  2018 2018-09-30
# 3805002               Riley Bullough  TAM  2018 2018-09-30
# 3805004                  Chris Conte  TAM  2018 2018-09-30
# 3805008                Carlton Davis  TAM  2018 2018-09-30
# 3805012              Maurice Fleming  TAM  2018 2018-09-30
# 3805013                 Cole Gardner  TAM  2018 2018-09-30
# 3805015            Vernon Hargreaves  TAM  2018 2018-09-30
# 3805016              De'Vante Harris  TAM  2018 2018-09-30
# 3805028                 Charles Sims  TAM  2018 2018-09-30
# 3805032          Stevie Tu'ikolovatu  TAM  2018 2018-09-30
# 3805033                 Mitch Unrein  TAM  2018 2018-09-30
# 3805034             Jordan Whitehead  TAM  2018 2018-09-30
# 3805035              Marcus Williams  TAM  2018 2018-09-30
# 3866493               Austin Barnard  TEN  2018 2018-09-30
# 3866494            Michael Campanaro  TEN  2018 2018-09-30
# 3866500            Johnathan Cyprien  TEN  2018 2018-09-30
# 3866501                   Kevin Dodd  TEN  2018 2018-09-30
# 3866504               David Fluellen  TEN  2018 2018-09-30
# 3866505               Blaine Gabbert  TEN  2018 2018-09-30
# 3866507                 Dennis Kelly  TEN  2018 2018-09-30
# 3866513             Rishard Matthews  TEN  2018 2018-09-30
# 3866514                 Johnny Maxey  TEN  2018 2018-09-30
# 3866517                  Nate Palmer  TEN  2018 2018-09-30
# 3866518               Kevin Pamphile  TEN  2018 2018-09-30
# 3866519              Gimel President  TEN  2018 2018-09-30
# 3866520                   Kalan Reed  TEN  2018 2018-09-30
# 3866521                   Devin Ross  TEN  2018 2018-09-30
# 3866525                    Tye Smith  TEN  2018 2018-09-30
# 3866529             Phillip Supernaw  TEN  2018 2018-09-30
# 3866531                   John Theus  TEN  2018 2018-09-30
# 3866533               Delanie Walker  TEN  2018 2018-09-30
# 3981813                Robert Alford  ARI  2019 2019-09-29
# 3981816                  Miles Brown  ARI  2019 2019-09-29
# 3981818                Hakeem Butler  ARI  2019 2019-09-29
# 3981819                 Damiere Byrd  ARI  2019 2019-09-29
# 3981824              Lamont Gaillard  ARI  2019 2019-09-29
# 3981825                   Max Garcia  ARI  2019 2019-09-29
# 3981827               Marcus Gilbert  ARI  2019 2019-09-29
# 3981835                     Andy Lee  ARI  2019 2019-09-29
# 3981848                    Josh Shaw  ARI  2019 2019-09-29
# 3981851                William Sweet  ARI  2019 2019-09-29
# 3981859           Charles Washington  ARI  2019 2019-09-29
# 3981860             Brandon Williams  ARI  2019 2019-09-29
# 4039479                Kenjon Barner  ATL  2019 2019-09-29
# 4039480                 Kurt Benkert  ATL  2019 2019-09-29
# 4039481              Michael Bennett  ATL  2019 2019-09-29
# 4039484                   Ryan Brown  ATL  2019 2019-09-29
# 4039485               Taveze Calhoun  ATL  2019 2019-09-29
# 4039493                    Alex Gray  ATL  2019 2019-09-29
# 4039494             Ra'Shede Hageman  ATL  2019 2019-09-29
# 4039500              Chris Lindstrom  ATL  2019 2019-09-29
# 4039502                 Steven Means  ATL  2019 2019-09-29
# 4039503                   Keanu Neal  ATL  2019 2019-09-29
# 4039512                   Matt Simms  ATL  2019 2019-09-29
# 4039516                  J.J. Wilcox  ATL  2019 2019-09-29
# 4100975                  Otaro Alaka  BAL  2019 2019-09-29
# 4100976                 Mark Andrews  BAL  2019 2019-09-29
# 4100986             Randin Crecelius  BAL  2019 2019-09-29
# 4100990              Marlon Humphrey  BAL  2019 2019-09-29
# 4101000                Iman Marshall  BAL  2019 2019-09-29
# 4101012                  Jimmy Smith  BAL  2019 2019-09-29
# 4101013                Fish Smithson  BAL  2019 2019-09-29
# 4101016              Brynden Trawick  BAL  2019 2019-09-29
# 4101020                  Tavon Young  BAL  2019 2019-09-29
# 4166318            Maurice Alexander  BUF  2019 2019-09-29
# 4166321                  Jason Croom  BUF  2019 2019-09-29
# 4166323                Jon Feliciano  BUF  2019 2019-09-29
# 4166325                Robert Foster  BUF  2019 2019-09-29
# 4166328                Taron Johnson  BUF  2019 2019-09-29
# 4166329                Vosean Joseph  BUF  2019 2019-09-29
# 4166330                  Tyler Kroft  BUF  2019 2019-09-29
# 4166333                 Spencer Long  BUF  2019 2019-09-29
# 4166334                    Mike Love  BUF  2019 2019-09-29
# 4166336              Isaiah McKenzie  BUF  2019 2019-09-29
# 4166341            Harrison Phillips  BUF  2019 2019-09-29
# 4166343             Devin Singletary  BUF  2019 2019-09-29
# 4166344               Corey Thompson  BUF  2019 2019-09-29
# 4166345              LaAdrian Waddle  BUF  2019 2019-09-29
# 4231646                 Kofi Amichia  CAR  2019 2019-09-29
# 4231647                 Marcus Baugh  CAR  2019 2019-09-29
# 4231654                  Graham Gano  CAR  2019 2019-09-29
# 4231656                Dillon Gordon  CAR  2019 2019-09-29
# 4231657               Brandon Greene  CAR  2019 2019-09-29
# 4231659               Marquis Haynes  CAR  2019 2019-09-29
# 4231661                  Bruce Irvin  CAR  2019 2019-09-29
# 4231662                Donte Jackson  CAR  2019 2019-09-29
# 4231672                   Cam Newton  CAR  2019 2019-09-29
# 4231673                 Kitt O'Brien  CAR  2019 2019-09-29
# 4231676                 Damian Parms  CAR  2019 2019-09-29
# 4231681                 Kawann Short  CAR  2019 2019-09-29
# 4231683                  Trai Turner  CAR  2019 2019-09-29
# 4231684                Destiny Vaeao  CAR  2019 2019-09-29
# 4289304                  Trey Burton  CHI  2019 2019-09-29
# 4289305               T.J. Clemmings  CHI  2019 2019-09-29
# 4289307               Taylor Gabriel  CHI  2019 2019-09-29
# 4289309                  Akiem Hicks  CHI  2019 2019-09-29
# 4289315                    Kyle Long  CHI  2019 2019-09-29
# 4289319                Bilal Nichols  CHI  2019 2019-09-29
# 4289320                 Eddy Pineiro  CHI  2019 2019-09-29
# 4289324               Joshua Simmons  CHI  2019 2019-09-29
# 4404597               Morgan Burnett  CLE  2019 2019-09-29
# 4404599                  Lo Falemaka  CLE  2019 2019-09-29
# 4404600                  Drew Forbes  CLE  2019 2019-09-29
# 4404604              Rashard Higgins  CLE  2019 2019-09-29
# 4404607                Chris Hubbard  CLE  2019 2019-09-29
# 4404610                 Joe Kerridge  CLE  2019 2019-09-29
# 4404611            Christian Kirksey  CLE  2019 2019-09-29
# 4404612                 Kendall Lamm  CLE  2019 2019-09-29
# 4404613              D.J. Montgomery  CLE  2019 2019-09-29
# 4404615                  David Njoku  CLE  2019 2019-09-29
# 4404617            Sheldrick Redwine  CLE  2019 2019-09-29
# 4404623                 Drew Stanton  CLE  2019 2019-09-29
# 4404628                  Denzel Ward  CLE  2019 2019-09-29
# 4404629              Greedy Williams  CLE  2019 2019-09-29
# 4458407                   Noah Brown  DAL  2019 2019-09-29
# 4458412              Tyrone Crawford  DAL  2019 2019-09-29
# 4458415               Michael Gallup  DAL  2019 2019-09-29
# 4458416                 Luke Gifford  DAL  2019 2019-09-29
# 4458419                  Jalen Jelks  DAL  2019 2019-09-29
# 4458420              Jon'Vea Johnson  DAL  2019 2019-09-29
# 4458423                 Lance Lenoir  DAL  2019 2019-09-29
# 4458426              Connor McGovern  DAL  2019 2019-09-29
# 4458429                 Derrick Puni  DAL  2019 2019-09-29
# 4458431                  Daniel Ross  DAL  2019 2019-09-29
# 4458439                 Chris Westry  DAL  2019 2019-09-29
# 4458440                Cody Wichmann  DAL  2019 2019-09-29
# 4458444                Antwaun Woods  DAL  2019 2019-09-29
# 4519903                    Jake Butt  DEN  2019 2019-09-29
# 4519904               Bryce Callahan  DEN  2019 2019-09-29
# 4519910                   Nico Falah  DEN  2019 2019-09-29
# 4519913                  Austin Fort  DEN  2019 2019-09-29
# 4519919               Kareem Jackson  DEN  2019 2019-09-29
# 4519920                Ja'Wuan James  DEN  2019 2019-09-29
# 4519921                Andy Janovich  DEN  2019 2019-09-29
# 4519922                 Josey Jewell  DEN  2019 2019-09-29
# 4519926                 Joseph Jones  DEN  2019 2019-09-29
# 4519928                    Drew Lock  DEN  2019 2019-09-29
# 4519933                 Dadi Nicolas  DEN  2019 2019-09-29
# 4519935                  Tim Patrick  DEN  2019 2019-09-29
# 4519938            Horace Richardson  DEN  2019 2019-09-29
# 4519939                 Theo Riddick  DEN  2019 2019-09-29
# 4519941               Dymonte Thomas  DEN  2019 2019-09-29
# 4519945                   Billy Winn  DEN  2019 2019-09-29
# 4519946                  Derek Wolfe  DEN  2019 2019-09-29
# 4581404               Danny Amendola  DET  2019 2019-09-29
# 4581407                Austin Bryant  DET  2019 2019-09-29
# 4581410                 Mike Daniels  DET  2019 2019-09-29
# 4581418                Da'Shawn Hand  DET  2019 2019-09-29
# 4581424              Jermaine Kearse  DET  2019 2019-09-29
# 4581426                 Darius Kilgo  DET  2019 2019-09-29
# 4581439                  Darius Slay  DET  2019 2019-09-29
# 4581440             Matthew Stafford  DET  2019 2019-09-29
# 4704410                 Duke Ejiofor  HOU  2019 2019-09-29
# 4704415           Seantrel Henderson  HOU  2019 2019-09-29
# 4704423               Senio Kelemete  HOU  2019 2019-09-29
# 4704424                Chris Landrum  HOU  2019 2019-09-29
# 4704428                 Lamar Miller  HOU  2019 2019-09-29
# 4704429              Charles Omenihu  HOU  2019 2019-09-29
# 4704432             Ira Savage-Lewis  HOU  2019 2019-09-29
# 4704434              David Steinmetz  HOU  2019 2019-09-29
# 4704436                Jordan Thomas  HOU  2019 2019-09-29
# 4704438               Kahale Warring  HOU  2019 2019-09-29
# 4704442                     Joe Webb  HOU  2019 2019-09-29
# 4704443                Isaac Whitney  HOU  2019 2019-09-29
# 4704444        Xavier Woodson-Luster  HOU  2019 2019-09-29
# 4769745                  Billy Brown  IND  2019 2019-09-29
# 4769748                 Pierre Desir  IND  2019 2019-09-29
# 4769751             Daurice Fountain  IND  2019 2019-09-29
# 4769752               Devin Funchess  IND  2019 2019-09-29
# 4769755                  T.Y. Hilton  IND  2019 2019-09-29
# 4769756                 Malik Hooker  IND  2019 2019-09-29
# 4769758                Steve Ishmael  IND  2019 2019-09-29
# 4769759            Iseoluwapo Jegede  IND  2019 2019-09-29
# 4769760               Isaiah Johnson  IND  2019 2019-09-29
# 4769762               Darius Leonard  IND  2019 2019-09-29
# 4769763                 Tyquan Lewis  IND  2019 2019-09-29
# 4769767           Al-Quadin Muhammad  IND  2019 2019-09-29
# 4769768                    Kai Nacua  IND  2019 2019-09-29
# 4769770              Javon Patterson  IND  2019 2019-09-29
# 4769772                Jabaal Sheard  IND  2019 2019-09-29
# 4831240               D.J. Alexander  JAX  2019 2019-09-29
# 4831242                  Alfred Blue  JAX  2019 2019-09-29
# 4831244                   Cody Brown  JAX  2019 2019-09-29
# 4831248                   Nick Foles  JAX  2019 2019-09-29
# 4831251               Donnell Greene  JAX  2019 2019-09-29
# 4831255                  Ben Ijalana  JAX  2019 2019-09-29
# 4831259                 Devante Mays  JAX  2019 2019-09-29
# 4831261                 KC McDermott  JAX  2019 2019-09-29
# 4831262                  Taj McGowan  JAX  2019 2019-09-29
# 4831268                  Josh Oliver  JAX  2019 2019-09-29
# 4831269                James Onwualu  JAX  2019 2019-09-29
# 4831270                 Jalen Ramsey  JAX  2019 2019-09-29
# 4831273                    Jake Ryan  JAX  2019 2019-09-29
# 4831274                 Marcus Simms  JAX  2019 2019-09-29
# 4831275                  Geoff Swaim  JAX  2019 2019-09-29
# 4892741                 Felton Davis  KAN  2019 2019-09-29
# 4892746                  Eric Fisher  KAN  2019 2019-09-29
# 4892748                Davon Grayson  KAN  2019 2019-09-29
# 4892749                Darius Harris  KAN  2019 2019-09-29
# 4892750                   Chad Henne  KAN  2019 2019-09-29
# 4892751                  Tyreek Hill  KAN  2019 2019-09-29
# 4892755                  Marcus Kemp  KAN  2019 2019-09-29
# 4892758                  John Lovett  KAN  2019 2019-09-29
# 4892769                 Keith Reaser  KAN  2019 2019-09-29
# 4892771              Breeland Speaks  KAN  2019 2019-09-29
# 4892773                     Tim Ward  KAN  2019 2019-09-29
# 4892776                  David Wells  KAN  2019 2019-09-29
# 4892777              Damien Williams  KAN  2019 2019-09-29
# 4958080              Michael Badgley  LAC  2019 2019-09-29
# 4958081              Travis Benjamin  LAC  2019 2019-09-29
# 4958084               Dylan Cantrell  LAC  2019 2019-09-29
# 4958090                 Virgil Green  LAC  2019 2019-09-29
# 4958091                Casey Hayward  LAC  2019 2019-09-29
# 4958092                 Hunter Henry  LAC  2019 2019-09-29
# 4958095               Justin Jackson  LAC  2019 2019-09-29
# 4958096                 Derwin James  LAC  2019 2019-09-29
# 4958097              Tre'von Johnson  LAC  2019 2019-09-29
# 4958101                  Koda Martin  LAC  2019 2019-09-29
# 4958106                Russell Okung  LAC  2019 2019-09-29
# 4958109              Adrian Phillips  LAC  2019 2019-09-29
# 4958115               Drue Tranquill  LAC  2019 2019-09-29
# 4958116               Andrew Vollert  LAC  2019 2019-09-29
# 4958118                Mike Williams  LAC  2019 2019-09-29
# 4958119              Trevor Williams  LAC  2019 2019-09-29
# 5019579                Josh Carraway  LAR  2019 2019-09-29
# 5019591                  Micah Kiser  LAR  2019 2019-09-29
# 5019592                Justin Lawler  LAR  2019 2019-09-29
# 5077220                  Chase Allen  MIA  2019 2019-09-29
# 5077227               James Crawford  MIA  2019 2019-09-29
# 5077229            Julie'n Davenport  MIA  2019 2019-09-29
# 5077230                  Jesse Davis  MIA  2019 2019-09-29
# 5077238                 Trent Harris  MIA  2019 2019-09-29
# 5077241                    Mike Hull  MIA  2019 2019-09-29
# 5077242                  Allen Hurns  MIA  2019 2019-09-29
# 5077243                Danny Isidora  MIA  2019 2019-09-29
# 5077245                 Reshad Jones  MIA  2019 2019-09-29
# 5077248           Jonathan Ledbetter  MIA  2019 2019-09-29
# 5077250                Ricardo Louis  MIA  2019 2019-09-29
# 5077251                 Bobby McCain  MIA  2019 2019-09-29
# 5077255             Robert Nkemdiche  MIA  2019 2019-09-29
# 5077256              Kendrick Norton  MIA  2019 2019-09-29
# 5077259                  Jamal Perry  MIA  2019 2019-09-29
# 5077263           Cordrea Tankersley  MIA  2019 2019-09-29
# 5077264            Andrew Van Ginkel  MIA  2019 2019-09-29
# 5077271                Albert Wilson  MIA  2019 2019-09-29
# 5077272             Jonathan Woodard  MIA  2019 2019-09-29
# 5134888          Mackensie Alexander  MIN  2019 2019-09-29
# 5134891                   Chad Beebe  MIN  2019 2019-09-29
# 5134892                Tashawn Bower  MIN  2019 2019-09-29
# 5134893            Kentrell Brothers  MIN  2019 2019-09-29
# 5134897                 Josh Doctson  MIN  2019 2019-09-29
# 5134909                   Josh Kline  MIN  2019 2019-09-29
# 5134911                 David Morgan  MIN  2019 2019-09-29
# 5134923               Isaiah Wharton  MIN  2019 2019-09-29
# 5192540                Alex Anzalone  NOR  2019 2019-09-29
# 5192545                   Drew Brees  NOR  2019 2019-09-29
# 5192547                   Will Clapp  NOR  2019 2019-09-29
# 5192553                 Kaden Elliss  NOR  2019 2019-09-29
# 5192556              Garrett Griffin  NOR  2019 2019-09-29
# 5192558                 Chase Hansen  NOR  2019 2019-09-29
# 5192562                Colton Jumper  NOR  2019 2019-09-29
# 5192564               Keith Kirkwood  NOR  2019 2019-09-29
# 5192568                  Josh Martin  NOR  2019 2019-09-29
# 5192570              Sheldon Rankins  NOR  2019 2019-09-29
# 5192573               Tre'Quan Smith  NOR  2019 2019-09-29
# 5192574                  Cameron Tom  NOR  2019 2019-09-29
# 5250193                David Andrews  NWE  2019 2019-09-29
# 5250194              Michael Bennett  NWE  2019 2019-09-29
# 5250199                 Rex Burkhead  NWE  2019 2019-09-29
# 5250200                Yodny Cajuste  NWE  2019 2019-09-29
# 5250206                Keionta Davis  NWE  2019 2019-09-29
# 5250207                James Develin  NWE  2019 2019-09-29
# 5250209                   Nate Ebner  NWE  2019 2019-09-29
# 5250210               Julian Edelman  NWE  2019 2019-09-29
# 5250212              Hjalte Froholdt  NWE  2019 2019-09-29
# 5250213                   Malik Gant  NWE  2019 2019-09-29
# 5250218                 N'Keal Harry  NWE  2019 2019-09-29
# 5250219             Dont'a Hightower  NWE  2019 2019-09-29
# 5250224                 Brandon King  NWE  2019 2019-09-29
# 5250225                 Matt LaCosse  NWE  2019 2019-09-29
# 5250229             Cameron Meredith  NWE  2019 2019-09-29
# 5250231            Marshall Newhouse  NWE  2019 2019-09-29
# 5250233                 Derek Rivers  NWE  2019 2019-09-29
# 5250234                D'Angelo Ross  NWE  2019 2019-09-29
# 5250243                  Isaiah Wynn  NWE  2019 2019-09-29
# 5311700                  Keion Adams  NYG  2019 2019-09-29
# 5311702           George Asafo-Adjei  NYG  2019 2019-09-29
# 5311704               Saquon Barkley  NYG  2019 2019-09-29
# 5311705                     Sam Beal  NYG  2019 2019-09-29
# 5311707                Corey Coleman  NYG  2019 2019-09-29
# 5311709                    Tae Davis  NYG  2019 2019-09-29
# 5311714               Amba Etta-Tawo  NYG  2019 2019-09-29
# 5311719                  Nate Harvey  NYG  2019 2019-09-29
# 5311723                Kareem Martin  NYG  2019 2019-09-29
# 5311724                Mark McLaurin  NYG  2019 2019-09-29
# 5311725                Alec Ogletree  NYG  2019 2019-09-29
# 5311730              Isaiah Searight  NYG  2019 2019-09-29
# 5311731              Russell Shepard  NYG  2019 2019-09-29
# 5415501              Johnathan Abram  OAK  2019 2019-09-29
# 5415503                  Trent Brown  OAK  2019 2019-09-29
# 5415508               Isaiah Crowell  OAK  2019 2019-09-29
# 5415509                 Jordan Devey  OAK  2019 2019-09-29
# 5415510            Makinton Dorleant  OAK  2019 2019-09-29
# 5415511                 Justin Ellis  OAK  2019 2019-09-29
# 5415515                Dwayne Harris  OAK  2019 2019-09-29
# 5415518                 Cameron Hunt  OAK  2019 2019-09-29
# 5415520                 Gabe Jackson  OAK  2019 2019-09-29
# 5415523               Isaiah Johnson  OAK  2019 2019-09-29
# 5415527                D.J. Killings  OAK  2019 2019-09-29
# 5415528                  Marquel Lee  OAK  2019 2019-09-29
# 5415535              Nathan Peterman  OAK  2019 2019-09-29
# 5415538             Eddie Vanderdoes  OAK  2019 2019-09-29
# 5588445                Ezekiel Ansah  SEA  2019 2019-09-29
# 5588448               Jeremy Boykins  SEA  2019 2019-09-29
# 5588453                  Adam Choice  SEA  2019 2019-09-29
# 5588454           Demarcus Christmas  SEA  2019 2019-09-29
# 5588457                Justin Currie  SEA  2019 2019-09-29
# 5588458                   Ed Dickson  SEA  2019 2019-09-29
# 5588461            Emmanuel Ellerbee  SEA  2019 2019-09-29
# 5588467                  Phil Haynes  SEA  2019 2019-09-29
# 5588472            Quinton Jefferson  SEA  2019 2019-09-29
# 5588473               Justin Johnson  SEA  2019 2019-09-29
# 5588474                 Nazair Jones  SEA  2019 2019-09-29
# 5588476               Demetrius Knox  SEA  2019 2019-09-29
# 5588479                Rashaad Penny  SEA  2019 2019-09-29
# 5588480                  Ethan Pocic  SEA  2019 2019-09-29
# 5588483                   Kalan Reed  SEA  2019 2019-09-29
# 5588484               Jordan Simmons  SEA  2019 2019-09-29
# 5588486                 Neiko Thorpe  SEA  2019 2019-09-29
# 5719133             Kendell Beckwith  TAM  2019 2019-09-29
# 5719136                   K.J. Brent  TAM  2019 2019-09-29
# 5719140                   Jamel Dean  TAM  2019 2019-09-29
# 5719141                 D'cota Dixon  TAM  2019 2019-09-29
# 5719142                 Demar Dotson  TAM  2019 2019-09-29
# 5719144                 Justin Evans  TAM  2019 2019-09-29
# 5719146               Blaine Gabbert  TAM  2019 2019-09-29
# 5719147                 Chris Godwin  TAM  2019 2019-09-29
# 5719150                  Ryan Jensen  TAM  2019 2019-09-29
# 5719152                 Mike Liedtke  TAM  2019 2019-09-29
# 5719155              Bryant Mitchell  TAM  2019 2019-09-29
# 5719159            Jason Pierre-Paul  TAM  2019 2019-09-29
# 5719163                Orion Stewart  TAM  2019 2019-09-29
# 5719164                  Devin White  TAM  2019 2019-09-29
# 5780624               Cameron Batson  TEN  2019 2019-09-29
# 5780641                  Joshua Kalu  TEN  2019 2019-09-29
# 5780644               Kevin Pamphile  TEN  2019 2019-09-29
# 5780648              Jeffery Simmons  TEN  2019 2019-09-29
# 5780651                  Ryan Succop  TEN  2019 2019-09-29
# 5780654               D'Andre Walker  TEN  2019 2019-09-29
# 5780656              Jordan Williams  TEN  2019 2019-09-29
# 5845957             Jordan Brailford  WAS  2019 2019-09-29
# 5845958               Caleb Brantley  WAS  2019 2019-09-29
# 5845963                   Casey Dunn  WAS  2019 2019-09-29
# 5845966                Reuben Foster  WAS  2019 2019-09-29
# 5845967                Derrius Guice  WAS  2019 2019-09-29
# 5845971               Myles Humphrey  WAS  2019 2019-09-29
# 5845972                Danny Johnson  WAS  2019 2019-09-29
# 5845975                   Bryce Love  WAS  2019 2019-09-29
# 5845979               Terry McLaurin  WAS  2019 2019-09-29
# 5845989                  Jordan Reed  WAS  2019 2019-09-29
# 5845991  Dominique Rodgers-Cromartie  WAS  2019 2019-09-29
# 5845992               Chase Roullier  WAS  2019 2019-09-29
# 5845993              Brandon Scherff  WAS  2019 2019-09-29
# 5845996                   Alex Smith  WAS  2019 2019-09-29
# 5845997                 Greg Stroman  WAS  2019 2019-09-29
# 5846000                 Shaun Wilson  WAS  2019 2019-09-29
# 5846001                 Josh Woodrum  WAS  2019 2019-09-29
# 334384                 Ka'Deem Carey  CHI  2017 2017-09-28
# 334388                 Quintin Demps  CHI  2017 2017-09-28
# 334390               Jerrell Freeman  CHI  2017 2017-09-28
# 334392                 Hroniss Grasu  CHI  2017 2017-09-28
# 334393                Deiondre' Hall  CHI  2017 2017-09-28
# 334395                Lamarr Houston  CHI  2017 2017-09-28
# 334401                     Eric Kush  CHI  2017 2017-09-28
# 334402               Nick Kwiatkoski  CHI  2017 2017-09-28
# 334408              Cameron Meredith  CHI  2017 2017-09-28
# 334411                 Rueben Randle  CHI  2017 2017-09-28
# 334415                Patrick Scales  CHI  2017 2017-09-28
# 334418                   Josh Sitton  CHI  2017 2017-09-28
# 334423                   Kevin White  CHI  2017 2017-09-28
# 703353              Montravius Adams  GNB  2017 2017-09-28
# 703355               David Bakhtiari  GNB  2017 2017-09-28
# 703356                   Don Barclay  GNB  2017 2017-09-28
# 703358                  Vince Biegel  GNB  2017 2017-09-28
# 703361                  Bryan Bulaga  GNB  2017 2017-09-28
# 703365                  Mike Daniels  GNB  2017 2017-09-28
# 703368                   Brett Goode  GNB  2017 2017-09-28
# 703369                Antwan Goodley  GNB  2017 2017-09-28
# 703370               Demetri Goodson  GNB  2017 2017-09-28
# 703371                   Davon House  GNB  2017 2017-09-28
# 703380                   Kyle Murphy  GNB  2017 2017-09-28
# 703384                    Nick Perry  GNB  2017 2017-09-28
# 703390                 Beau Sandland  GNB  2017 2017-09-28
# 703391                 Jason Spriggs  GNB  2017 2017-09-28
# 703394                   Herb Waters  GNB  2017 2017-09-28
# 3093962                  Mark Barron  LAR  2018 2018-09-27
# 3093964                Pharoh Cooper  LAR  2018 2018-09-27
# 3093966                   Ryan Davis  LAR  2018 2018-09-27
# 3093967             Dominique Easley  LAR  2018 2018-09-27
# 3093968                   Morgan Fox  LAR  2018 2018-09-27
# 3093974           Ogbonnia Okoronkwo  LAR  2018 2018-09-27
# 3093975                Marcus Peters  LAR  2018 2018-09-27
# 3093976               Kevin Peterson  LAR  2018 2018-09-27
# 3093978              Garrett Sickels  LAR  2018 2018-09-27
# 3093979                   Aqib Talib  LAR  2018 2018-09-27
# 3093980                  Mike Thomas  LAR  2018 2018-09-27
# 3093981              Carlos Thompson  LAR  2018 2018-09-27
# 3093985                Greg Zuerlein  LAR  2018 2018-09-27
# 3224621                    Ade Aruna  MIN  2018 2018-09-27
# 3224626                   Mack Brown  MIN  2018 2018-09-27
# 3224627              Aviante Collins  MIN  2018 2018-09-27
# 3224629                  Dalvin Cook  MIN  2018 2018-09-27
# 3224631                  Nick Easton  MIN  2018 2018-09-27
# ...
# 2062592                           Out  CHI      9   23              Fibula
# 2062593                           Out  CHI      9   23                 Hip
# 2062604                           Out  CHI      9   23          Concussion
# 2062606               Injured Reserve  CHI      9   23
# 2062611  Physically Unable to Perform  CHI      9   23
# 2062612               Injured Reserve  CHI      9   23
# 2062615               Injured Reserve  CHI      9   23
# 2062616               Injured Reserve  CHI      9   23
# 2121601                           Out  NOR      9   23                Knee
# 2121607               Injured Reserve  NOR      9   23                Foot
# 2121609               Injured Reserve  NOR      9   23              Tricep
# 2121611                           Out  NOR      9   23               Groin
# 2121612               Injured Reserve  NOR      9   23                Knee
# 2121613                           Out  NOR      9   23                Calf
# 2121616                           Out  NOR      9   23               Groin
# 2179234               Injured Reserve  DEN      9   23                 Leg
# 2179235                           Out  DEN      9   23           Hamstring
# 2179238               Injured Reserve  DEN      9   23                Knee
# 2179240               Injured Reserve  DEN      9   23               Thigh
# 2179243               Injured Reserve  DEN      9   23                Knee
# 2179245               Injured Reserve  DEN      9   23             Forearm
# 2179248                           Out  DEN      9   23             Abdomen
# 2179249               Injured Reserve  DEN      9   23                Knee
# 2179251                           Out  DEN      9   23                Foot
# 2179253               Injured Reserve  DEN      9   23         Undisclosed
# 2179254               Injured Reserve  DEN      9   23             Forearm
# 2179256                  Questionable  DEN      9   23           Hamstring
# 2179260               Injured Reserve  DEN      9   23         Undisclosed
# 2179261                  Questionable  DEN      9   23                Knee
# 2179262                  Questionable  DEN      9   23                Foot
# 2179263               Injured Reserve  DEN      9   23    Coach's Decision
# 2179264               Injured Reserve  DEN      9   23                 Toe
# 2179267                  Questionable  DEN      9   23               Elbow
# 2179269               Injured Reserve  DEN      9   23            Personal
# 2179271               Injured Reserve  DEN      9   23          Upper Body
# 2244577               Injured Reserve  MIN      9   23                Knee
# 2244580                  Questionable  MIN      9   23               Elbow
# 2244581               Injured Reserve  MIN      9   23         Undisclosed
# 2244586                  Questionable  MIN      9   23            Shoulder
# 2244587                  Questionable  MIN      9   23                Head
# 2244588                           Out  MIN      9   23           Hamstring
# 2244590                  Questionable  MIN      9   23                Knee
# 2244591                  Questionable  MIN      9   23                 Rib
# 2298376                  Questionable  CIN      9   23                Knee
# 2298377               Injured Reserve  CIN      9   23                Shin
# 2298384               Injured Reserve  CIN      9   23                Knee
# 2298385                  Questionable  CIN      9   23               Groin
# 2298387               Injured Reserve  CIN      9   23                Knee
# 2298395                           Out  CIN      9   23                Foot
# 2298396               Injured Reserve  CIN      9   23            Shoulder
# 2298398               Injured Reserve  CIN      9   23                 Hip
# 2298399                           Out  CIN      9   23             Illness
# 2298400               Injured Reserve  CIN      9   23          Concussion
# 2298401               Injured Reserve  CIN      9   23            Shoulder
# 2298404               Injured Reserve  CIN      9   23           Hamstring
# 2298408                           Out  CIN      9   23          Concussion
# 2298409               Injured Reserve  CIN      9   23                Knee
# 2298410               Injured Reserve  CIN      9   23                Knee
# 2352189               Injured Reserve  ARI      9   23          Concussion
# 2352192                           Out  ARI      9   23           Hamstring
# 2352195                           Out  ARI      9   23             Forearm
# 2352203               Injured Reserve  ARI      9   23                 Leg
# 2352206               Injured Reserve  ARI      9   23                Foot
# 2352209               Injured Reserve  ARI      9   23         Undisclosed
# 2417508               Injured Reserve  CAR      9   23                Knee
# 2417509               Injured Reserve  CAR      9   23         Undisclosed
# 2417512                  Questionable  CAR      9   23               Ankle
# 2417513               Injured Reserve  CAR      9   23          Suspension
# 2417514               Injured Reserve  CAR      9   23           Hamstring
# 2417515               Injured Reserve  CAR      9   23            Shoulder
# 2417525               Injured Reserve  CAR      9   23                Knee
# 2417526               Injured Reserve  CAR      9   23                 Arm
# 2417530                  Questionable  CAR      9   23                Knee
# 2417534               Injured Reserve  CAR      9   23            Personal
# 2417537                           Out  CAR      9   23                Knee
# 2417539                           Out  CAR      9   23                Foot
# 2417544               Injured Reserve  CAR      9   23                Knee
# 2540499                  Questionable  SEA      9   23               Ankle
# 2540501               Injured Reserve  SEA      9   23           Hamstring
# 2540503                           Out  SEA      9   23                Knee
# 2540505               Injured Reserve  SEA      9   23                Knee
# 2540507               Injured Reserve  SEA      9   23             Illness
# 2540516                  Questionable  SEA      9   23           Hamstring
# 2540518               Injured Reserve  SEA      9   23                 Toe
# 2540522               Injured Reserve  SEA      9   23                Knee
# 2540531               Injured Reserve  SEA      9   23            Shoulder
# 2540533                  Questionable  SEA      9   23           Hamstring
# 2605832               Injured Reserve  BAL      9   23           Hamstring
# 2605835               Injured Reserve  BAL      9   23           Hamstring
# 2605836               Injured Reserve  BAL      9   23                Knee
# 2605840               Injured Reserve  BAL      9   23               Groin
# 2605842               Injured Reserve  BAL      9   23                Knee
# 2605846               Injured Reserve  BAL      9   23            Personal
# 2605849                  Questionable  BAL      9   23               Thigh
# 2605855                  Questionable  BAL      9   23                Knee
# 2605857               Injured Reserve  BAL      9   23            Achilles
# 2605863               Injured Reserve  BAL      9   23                 Hip
# 2605864                  Questionable  BAL      9   23             Abdomen
# 2605865                  Questionable  BAL      9   23          Concussion
# 2605866               Injured Reserve  BAL      9   23            Pectoral
# 2663485                  Questionable  NWE      9   23            Shoulder
# 2663486               Injured Reserve  NWE      9   23         Undisclosed
# 2663488               Injured Reserve  NWE      9   23                Knee
# 2663492               Injured Reserve  NWE      9   23                Knee
# 2663496                           Out  NWE      9   23                Knee
# 2663500                  Questionable  NWE      9   23                 Hip
# 2663504               Injured Reserve  NWE      9   23         Undisclosed
# 2663505                  Questionable  NWE      9   23               Ankle
# 2663507                  Questionable  NWE      9   23                Back
# 2663509               Injured Reserve  NWE      9   23                Knee
# 2663513                  Questionable  NWE      9   23                Knee
# 2663516                  Questionable  NWE      9   23          Concussion
# 2663522               Injured Reserve  NWE      9   23         Undisclosed
# 2663525               Injured Reserve  NWE      9   23                Back
# 2721151                  Questionable  WAS      9   23            Shoulder
# 2721155               Injured Reserve  WAS      9   23            Personal
# 2721159               Injured Reserve  WAS      9   23           Hamstring
# 2721162                  Questionable  WAS      9   23               Bicep
# 2721164                  Questionable  WAS      9   23               Ankle
# 2721165                           Out  WAS      9   23               Groin
# 2721166               Injured Reserve  WAS      9   23            Shoulder
# 2721167               Injured Reserve  WAS      9   23            Personal
# 2721170               Injured Reserve  WAS      9   23               Ankle
# 2721174                  Questionable  WAS      9   23                Knee
# 2721175               Injured Reserve  WAS      9   23                Knee
# 2722174               Injured Reserve  WAS      9   23
# 2722176                  Questionable  WAS      9   23               Groin
# 2722177               Injured Reserve  WAS      9   23
# 2722184                  Questionable  WAS      9   23            Shoulder
# 2722187                  Questionable  WAS      9   23                 Hip
# 2722191                           Out  WAS      9   23                Hand
# 2722192                  Questionable  WAS      9   23                Knee
# 2722196               Injured Reserve  WAS      9   23
# 2774957                  Questionable  NYG      9   23           Hamstring
# 2774960                  Questionable  NYG      9   23           Hamstring
# 2774966               Injured Reserve  NYG      9   23            Achilles
# 2774969               Injured Reserve  NYG      9   23                Knee
# 2774971               Injured Reserve  NYG      9   23             Illness
# 2774972               Injured Reserve  NYG      9   23               Ankle
# 2774973               Injured Reserve  NYG      9   23               Ankle
# 2774975               Injured Reserve  NYG      9   23          Concussion
# 2774978               Injured Reserve  NYG      9   23         Undisclosed
# 2774981               Injured Reserve  NYG      9   23         Undisclosed
# 2774983                  Questionable  NYG      9   23                 Hip
# 2774987                           Out  NYG      9   23            Achilles
# 2836446                           Out  PHI      9   23               Ankle
# 2836447               Injured Reserve  PHI      9   23                Knee
# 2836448               Injured Reserve  PHI      9   23         Undisclosed
# 2836449                           Out  PHI      9   23           Hamstring
# 2836450               Injured Reserve  PHI      9   23          Concussion
# 2836451                           Out  PHI      9   23                 Hip
# 2836454               Injured Reserve  PHI      9   23               Groin
# 2836456                  Questionable  PHI      9   23                Knee
# 2836457               Injured Reserve  PHI      9   23                Back
# 2836463               Injured Reserve  PHI      9   23         Undisclosed
# 2836467               Injured Reserve  PHI      9   23         Undisclosed
# 2836470               Injured Reserve  PHI      9   23          Concussion
# 2836471               Injured Reserve  PHI      9   23                Back
# 2836473               Injured Reserve  PHI      9   23                Back
# 2836477               Injured Reserve  PHI      9   23                Foot
# 2836478               Injured Reserve  PHI      9   23              Pelvis
# 2836479                           Out  PHI      9   23                Foot
# 2836480               Injured Reserve  PHI      9   23            Shoulder
# 2836482               Injured Reserve  PHI      9   23               Ankle
# 2836483                  Questionable  PHI      9   23          Concussion
# 2836490                           Out  PHI      9   23                Calf
# 2836496               Injured Reserve  PHI      9   23         Undisclosed
# 2836497               Injured Reserve  PHI      9   23                Knee
# 2836504               Injured Reserve  PHI      9   23           Hamstring
# 2836505                           Out  PHI      9   23          Concussion
# 2836507               Injured Reserve  PHI      9   23                Knee
# 2905646               Injured Reserve  TEN      9   23               Ankle
# 2905650                  Questionable  TEN      9   23              Tricep
# 2905651               Injured Reserve  TEN      9   23           Hamstring
# 2905653               Injured Reserve  TEN      9   23         Undisclosed
# 2905656               Injured Reserve  TEN      9   23         Undisclosed
# 2905657                  Questionable  TEN      9   23           Hamstring
# 2905659               Injured Reserve  TEN      9   23         Undisclosed
# 2905661               Injured Reserve  TEN      9   23                Knee
# 2905663                  Questionable  TEN      9   23                 Toe
# 2905664               Injured Reserve  TEN      9   23         Undisclosed
# 2905669               Injured Reserve  TEN      9   23                Knee
# 2905670               Injured Reserve  TEN      9   23         Undisclosed
# 2905681                  Questionable  TEN      9   23               Ankle
# 2905683               Injured Reserve  TEN      9   23                Knee
# 2905686               Injured Reserve  TEN      9   23         Undisclosed
# 2905687               Injured Reserve  TEN      9   23                Knee
# 2905691                  Questionable  TEN      9   23               Ankle
# 2967148                      Doubtful  SFO      9   23                Heel
# 2967150               Injured Reserve  SFO      9   23         Undisclosed
# 2967156               Injured Reserve  SFO      9   23            Shoulder
# 2967161               Injured Reserve  SFO      9   23               Ankle
# 2967162               Injured Reserve  SFO      9   23                Knee
# 2967164               Injured Reserve  SFO      9   23         Undisclosed
# 2967167                      Doubtful  SFO      9   23           Hamstring
# 2967169               Injured Reserve  SFO      9   23           Hamstring
# 2967170               Injured Reserve  SFO      9   23           Quadricep
# 2967172               Injured Reserve  SFO      9   23                Knee
# 2967174                  Questionable  SFO      9   23                Knee
# 3028636                           Out  LAR      9   23                Knee
# 3028637                  Questionable  LAR      9   23                Foot
# 3028638                           Out  LAR      9   23                Foot
# 3028639               Injured Reserve  LAR      9   23           Hamstring
# 3028645                  Questionable  LAR      9   23             Illness
# 3028647               Injured Reserve  LAR      9   23                Knee
# 3028650               Injured Reserve  LAR      9   23           Hamstring
# 3028655               Injured Reserve  LAR      9   23                Knee

# %%
stats_snaps = pd.merge(left=stats,right=snaps,how='outer',on=['Player','Year','Week'])
stats_snaps['Team_x'] = stats_snaps['Team_x'].fillna(stats_snaps['Team_y'])
stats_snaps['Pos_x'] = stats_snaps['Pos_y'].fillna(stats_snaps['Pos_x'])
stats_snaps.drop(['Team_y','Pos_y'],axis=1,inplace=True)
stats_snaps.rename(columns={'Team_x':'Team','Pos_x':'Pos'},inplace=True)

for col in stats_snaps.columns:
    print(col)

# %%
stats_snaps_injury = pd.merge(left=stats_snaps,right=injury,how='outer',on=['Player','Date'])
stats_snaps_injury.sort_values(by='Status',ascending=True,inplace=True)
stats_snaps_injury.to_csv('test.csv')

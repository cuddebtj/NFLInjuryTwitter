# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
from dotenv import load_dotenv
load_dotenv()

page = 0
login_url = "https://stathead.com/users/login.cgi"
user_name = os.environ.get('statheadusername')
password = os.environ.get('statheadpassword')
payload = {
    'username': user_name,
    'password': password
}
url = "https://stathead.com/football/tgl_finder.cgi?request=1&temperature_gtlt=lt&game_num_max=99&week_num_max=99&order_by=plays_offense&match=game&year_max=2019&order_by_asc=0&week_num_min=0&game_type=R&game_num_min=0&year_min=2017&offset="
print(user_name, password)
print(os.environ)
# Out:
# None None
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\cudde\\AppData\\Roaming', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-QVFL5M2', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'base', 'CONDA_EXE': 'C:\\Users\\cudde\\anaconda3\\Scripts\\conda.exe', 'CONDA_PROMPT_MODIFIER': '(base) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\cudde\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\cudde\\anaconda3', 'CONDA_SHLVL': '1', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\cudde', 'LOCALAPPDATA': 'C:\\Users\\cudde\\AppData\\Local', 'LOGONSERVER': '\\\\DESKTOP-QVFL5M2', 'NUMBER_OF_PROCESSORS': '6', 'ONEDRIVE': 'C:\\Users\\cudde\\OneDrive', 'ONEDRIVECONSUMER': 'C:\\Users\\cudde\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'C:\\Users\\cudde\\anaconda3;C:\\Users\\cudde\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\cudde\\anaconda3\\Library\\usr\\bin;C:\\Users\\cudde\\anaconda3\\Library\\bin;C:\\Users\\cudde\\anaconda3\\Scripts;C:\\Users\\cudde\\anaconda3\\bin;C:\\Users\\cudde\\anaconda3\\condabin;C:\\Users\\cudde\\anaconda3;C:\\Users\\cudde\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\cudde\\anaconda3\\Library\\usr\\bin;C:\\Users\\cudde\\anaconda3\\Library\\bin;C:\\Users\\cudde\\anaconda3\\Scripts;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Program Files\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Users\\cudde\\anaconda3;C:\\Users\\cudde\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\cudde\\anaconda3\\Library\\usr\\bin;C:\\Users\\cudde\\anaconda3\\Library\\bin;C:\\Users\\cudde\\anaconda3\\Scripts;C:\\Users\\cudde\\AppData\\Local\\Programs\\Python\\Python38\\Scripts;C:\\Users\\cudde\\AppData\\Local\\Programs\\Python\\Python38;C:\\Users\\cudde\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\cudde\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\cudde\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Program Files\\JetBrains\\PyCharm Community Edition 2020.1.2\\bin;.;C:\\Users\\cudde\\AppData\\Local\\Microsoft\\WindowsApps;.', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 158 Stepping 10, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '9e0a', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(base) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules;C:\\Program Files\\Intel\\Wired Networking\\', 'PUBLIC': 'C:\\Users\\Public', 'PYCHARM COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\PyCharm Community Edition 2020.1.2\\bin;', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\cudde\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\cudde\\AppData\\Local\\Temp', 'USERDOMAIN': 'DESKTOP-QVFL5M2', 'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-QVFL5M2', 'USERNAME': 'cudde', 'USERPROFILE': 'C:\\Users\\cudde', 'WINDIR': 'C:\\WINDOWS', 'CONDA_PREFIX': 'C:\\Users\\cudde\\anaconda3', 'JPY_INTERRUPT_EVENT': '2228', 'IPY_INTERRUPT_EVENT': '2228', 'JPY_PARENT_PID': '2232', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline', 'TWITTER_API_KEY': 'eBEx9DLIeFoHYvbJgYPH2XVVN', 'TWITTER_API_SECRET_KEY': 'GCCPY8Dzo5dFOf24FS5BsH7SNKsoh5eDF4P3FjzzMBJv0QScsx', 'TWITTER_BEARER_TOKEN': 'AAAAAAAAAAAAAAAAAAAAAB0oHwEAAAAAEsis4fmLGK ...

# %%
# with requests.Session() as session:
#     s = session.post(login_url, data=payload)
#     while page < 1600:
#         page1 = str(page)
#         website = session.get(url+page1).text
#         soup = BeautifulSoup(website, 'html')
#         #print(soup.prettify())
#         table = soup.find('table', attrs={'class': 'sortable', 'id': 'results'})

#         table_headers = [header.text for header in table.find('thead').find_all('th')]
#         table_rows = table.find_all('tr')

#         final_data = []
#         for tr in table_rows:
#             td = tr.find_all('td')
#             row = [tr.text for tr in td]
#             final_data.append(row)
#         df = pd.DataFrame(final_data, columns=table_headers[3:])
#         df.to_csv('nflteamsnaps.csv',mode='a',header=False)
#         page += 100
#         print(page)
# Out:
# 100

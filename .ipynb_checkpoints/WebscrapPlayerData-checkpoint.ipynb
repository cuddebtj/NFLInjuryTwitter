# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

page = 0
login_url = "https://stathead.com/users/login.cgi"
payload = {
    'username':'cuddebtj',
    'password':'tC322011'
}
url = "https://stathead.com/football/pgl_finder.cgi?request=1&game_num_max=99&week_num_max=99&order_by=all_td&game_month=&stadium_id=&season_start=1&qb_gwd=0&opp_id=&is_starter=&order_by_asc=0&qb_comeback=0&game_result=&week_num_min=0&game_day_of_week=&game_location=&game_num_min=0&league_id=&year_min=2017&is_hof=&match=game&team_id=&year_max=2019&playoff_round=&season_end=-1&is_active=&age_min=0&game_type=R&age_max=99&time_zone=&handedness=&positions[]=qb&positions[]=wr&positions[]=te&positions[]=e&positions[]=t&positions[]=g&positions[]=ol&positions[]=dt&positions[]=de&positions[]=dl&positions[]=ilb&positions[]=lb&positions[]=cb&positions[]=s&positions[]=db&positions[]=p&cstat[1]=\%20targets&ccomp[1]=gt&cval[1]=0&cstat[2]=pass_att&ccomp[2]=gt&cval[2]=0&cstat[3]=rush_att&ccomp[3]=gt&cval[3]=0&cstat[4]=touches&ccomp[4]=gt&cval[4]=0&cstat[5]=two_pt_md&ccomp[5]=gt&cval[5]=0&cstat[6]=kick_ret_td&ccomp[6]=gt&cval[6]=0&offset=0"

# %%
with requests.Session() as session:
    s = session.post(login_url, data=payload)
    while page < 46400:
        page1 = str(page)
        website = session.get(url+page1).text
        soup = BeautifulSoup(website, 'html')

        table = soup.find('table', attrs={'class': 'sortable', 'id': 'results'})

        table_headers = [header.text for header in table.find('thead').find_all('th')]
        table_rows = table.find_all('tr')

        final_data = []
        for tr in table_rows:
            td = tr.find_all('td')
            row = [tr.text for tr in td]
            final_data.append(row)
        df = pd.DataFrame(final_data, columns=table_headers[7:])
        df.to_csv('nfldata.csv',mode='a',header=False)
        page += 100
        print(page)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-426e96c42041> in <module>
#       3     while page < 46400:
#       4         page1 = str(page)
# ----> 5         website = session.get(url+page1).text
#       6         soup = BeautifulSoup(website, 'lxml')
#       7
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# ...

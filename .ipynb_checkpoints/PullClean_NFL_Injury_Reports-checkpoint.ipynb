# %%
import pandas as pd
import datetime as dt
from bs4 import BeautifulSoup
import requests

# %%
def webscrap_nfl_injury_reports(Start_Year,End_Year):
    #list of the NFL teams for url purposes
    teams = ['crd', 'atl', 'rav', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb','htx','clt','jax','kan',
             'sdg','ram','mia','min','nor','nwe','nyg','nyj','rai','phi','pit','sea','sfo','tam','oti','was']
    years = []
    
    #list of years to pull data for url purposes
    for yr in range(Start_Year,End_Year+1):
        years.append(yr)

    #starting points to iterate through
    team = 0
    year = 0
    dfname = []
    
    while team < 2:
        
        dfname.append(f'{teams[team]}_{years[year]}_injuryreport')
        
        #url for web scraping
        url = f'https://www.pro-football-reference.com/teams/{teams[team]}/{years[year]}_injuries.htm'
        
        #opening website
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'lxml')
        
        #finding table
        table = soup.find('table', attrs={'class': 'sortable', 'id': 'team_injuries'})
        table_rows = table.find_all('tr')

        #scraping the data
        final_data = []
        for tr in table_rows:
            td = tr.find_all(['th','td'])
            row = [tr['data-tip'] if tr.has_attr("data-tip") else tr.text for tr in td]
            final_data.append(row)

        #creatingdataframe to save
        dfdata = final_data[1:]
        data_body = [[dfdata[j][i] for j in range(len(dfdata))] for i in range(len(dfdata[0]))]
        data = {key: pd.DataFrame(data_body,final_data[0]).T for key in dfname}
        
        key = f'{teams[team]}_{years[year]}_injuryreport'
        
        data[key].insert(loc=1,column='Team',value=teams[team],allow_duplicates=True)
        data[key].insert(loc=2,column='Year',value=years[year],allow_duplicates=True)
        data[key].to_csv(f'{key}.csv',index=True)

        # update of location of web scrape
        print(teams[team],years[year])

        #advancing through url
        if year < len(years)-1:
            year += 1

        else:
            year = 0
            team += 1

# %%
webscrap_nfl_injury_reports(2017,2019)

# %%
Start_Year = 2017
End_Year = 2019

dfname = []
teams = ['crd', 'atl']#, 'rav', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb','htx','clt','jax','kan',
                 #'sdg','ram','mia','min','nor','nwe','nyg','nyj','rai','phi','pit','sea','sfo','tam','oti','was']

for team in teams:
    for year in range(Start_Year,End_Year+1):
        dfname.append(f'{team}_{year}_injuryreport')
        data = {key: pd.read_csv(f'{key}.csv') for key in dfname}

for key in data:
    data[key].drop('Unnamed: 0',axis=1,inplace=True)
    data[key] = pd.melt(data[key],id_vars=['Player','Team','Year'],var_name='Date', value_name='Status')
    data[key][['Date','Opp']] = data[key].Date.str.split("vs. ",expand=True)
    data[key][['Status','Injury']] = data[key].Status.str.split(":",expand=True)
    data[key]['Date'] = data[key]['Date'].astype(str)+'/'+data[key]['Year'].astype(str)
    data[key]['Date'] = pd.to_datetime(data[key]['Date'])
#     data[key].replace({'Team':\
#                        {'crd':'ARI', 'atl':'ATL', 'rav':'BAL', 'buf':'BUF', 'car':'CAR', 'chi':'CHI', 'cin':'CIN',\
#                         'cle':'CLE', 'dal':'DAL', 'den':'DEN', 'det':'DET', 'gnb':'GNB','htx':'HOU','clt':'IND',\
#                         'jax':'JAX','kan':'KAN','sdg':'LAC','ram':'LAR','mia':'MIA','min':'MIN','nor':'NOR','nwe':'NWE',\
#                         'nyg':'NYG','nyj':'NYJ','rai':'OAK','phi':'PHI','pit':'PIT','sea':'SEA','sfo':'SFO','tam':'TAM',\
#                         'oti':'TEN','was':'WAS'},'Opp':{}},inplace=True)
    #data[key].dropna(thresh=3,inplace=True)

print(data)

# player_snaps = pd.merge(left=player,right=team,how='outer',left_on=['Team','Year','Week'],right_on=['Tm','Year','Week'])

# print(player)
# print(team)
# print(player_snaps)
# player_snaps.to_csv(f'player_snaps_{Start_Year}_{End_Year}.csv',index=False)
# Out:
# {'crd_2017_injuryreport':                Player Team  Year       Date           Status  Opp      Injury
# 0      Antoine Bethea  crd  2017 2017-09-10              NaN  DET         NaN
# 1         Alex Boone   crd  2017 2017-09-10              NaN  DET         NaN
# 2        Tyvon Branch  crd  2017 2017-09-10              NaN  DET         NaN
# 3        Aaron Brewer  crd  2017 2017-09-10              NaN  DET         NaN
# 4          John Brown  crd  2017 2017-09-10              NaN  DET         NaN
# ..                ...  ...   ...        ...              ...  ...         ...
# 683       John Wetzel  crd  2017 2017-12-31              NaN  SEA         NaN
# 684     Chad Williams  crd  2017 2017-12-31              NaN  SEA         NaN
# 685  Kerwynn Williams  crd  2017 2017-12-31     Questionable  SEA   Quadricep
# 686   Xavier Williams  crd  2017 2017-12-31              NaN  SEA         NaN
# 687     Ronald Zamort  crd  2017 2017-12-31  Injured Reserve  SEA        Knee
#
# [688 rows x 7 columns], 'crd_2018_injuryreport':                   Player Team  Year       Date           Status  Opp  \
# 0        Bryson Albright  crd  2018 2018-09-09  Injured Reserve  WAS
# 1    Thurston Armbrister  crd  2018 2018-09-09              NaN  WAS
# 2           Budda Baker   crd  2018 2018-09-09              NaN  WAS
# 3         Bene Benwikere  crd  2018 2018-09-09              NaN  WAS
# 4             Tre Boston  crd  2018 2018-09-09              NaN  WAS
# ..                   ...  ...   ...        ...              ...  ...
# 683          Andre Smith  crd  2018 2018-12-30              NaN  SEA
# 684         Jamar Taylor  crd  2018 2018-12-30              NaN  SEA
# 685     Jeremy Vujnovich  crd  2018 2018-12-30  Injured Reserve  SEA
# 686          John Wetzel  crd  2018 2018-12-30  Injured Reserve  SEA
# 687        Chad Williams  crd  2018 2018-12-30              NaN  SEA
#
#            Injury
# 0     Undisclosed
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 683           NaN
# 684           NaN
# 685     Hamstring
# 686          Neck
# 687           NaN
#
# [688 rows x 7 columns], 'crd_2019_injuryreport':                  Player Team  Year       Date           Status  Opp Injury
# 0         Robert Alford  crd  2019 2019-09-08  Injured Reserve  DET
# 1            Zach Allen  crd  2019 2019-09-08              NaN  DET    NaN
# 2       Tramaine Brock   crd  2019 2019-09-08              NaN  DET    NaN
# 3           Miles Brown  crd  2019 2019-09-08              NaN  DET    NaN
# 4      Jonathan Bullard  crd  2019 2019-09-08              NaN  DET    NaN
# ..                  ...  ...   ...        ...              ...  ...    ...
# 795          Joe Walker  crd  2019 2019-12-29              NaN  LAR    NaN
# 796  Charles Washington  crd  2019 2019-12-29              NaN  LAR    NaN
# 797    Brandon Williams  crd  2019 2019-12-29  Injured Reserve  LAR
# 798       Maxx Williams  crd  2019 2019-12-29              NaN  LAR    NaN
# 799     Trevor Williams  crd  2019 2019-12-29              NaN  LAR    NaN
#
# [800 rows x 7 columns], 'atl_2017_injuryreport':                 Player Team  Year       Date           Status  Opp  \
# 0        Ricardo Allen  atl  2017 2017-09-10              NaN  CHI
# 1          Vic Beasley  atl  2017 2017-09-10              NaN  CHI
# 2       Matthew Bosher  atl  2017 2017-09-10              NaN  CHI
# 3          Matt Bryant  atl  2017 2017-09-10              NaN  CHI
# 4        Tevin Coleman  atl  2017 2017-09-10              NaN  CHI
# ..                 ...  ...   ...        ...              ...  ...
# 463       Jordan Tripp  atl  2017 2017-01-13  Injured Reserve  PHI
# 464    Desmond Trufant  atl  2017 2017-01-13              NaN  PHI
# 465    Courtney Upshaw  atl  2017 2017-01-13              NaN  PHI
# 466        Terron Ward  atl  2017 2017-01-13              NaN  PHI
# 467  Sean Weatherspoon  atl  2017 2017-01-13              NaN  PHI
#
#           Injury
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 463   Concussion
# 464          NaN
# 465          NaN
# 466          NaN
# 467          NaN
#
# [468 rows x 7 columns], 'atl_2018_injuryreport':                 Player Team  Year       Date           Status  Opp  Injury
# 0        Robert Alford  atl  2018 2018-09-06              NaN  PHI     NaN
# 1        Ricardo Allen  atl  2018 2018-09-06              NaN  PHI     NaN
# 2        Justin Bethel  atl  2018 2018-09-06              NaN  PHI     NaN
# 3          Matt Bryant  atl  2018 2018-09-06              NaN  PHI     NaN
# 4     Devonta Freeman   atl  2018 2018-09-06              NaN  PHI     NaN
# ..                 ...  ...   ...        ...              ...  ...     ...
# 347      Logan Paulsen  atl  2018 2018-12-30              NaN  TAM     NaN
# 348    Wes Schweitzer   atl  2018 2018-12-30              Out  TAM    Back
# 349     Derrick Shelby  atl  2018 2018-12-30  Injured Reserve  TAM   Groin
# 350          Ito Smith  atl  2018 2018-12-30  Injured Reserve  TAM    Knee
# 351  Blidi Wreh-Wilson  atl  2018 2018-12-30              NaN  TAM     NaN
#
# [352 rows x 7 columns], 'atl_2019_injuryreport':                 Player Team  Year       Date           Status  Opp Injury
# 0         Allen Bailey  atl  2019 2019-09-08              NaN  MIN    NaN
# 1        Kenjon Barner  atl  2019 2019-09-08              NaN  MIN    NaN
# 2         Kurt Benkert  atl  2019 2019-09-08  Injured Reserve  MIN
# 3      Michael Bennett  atl  2019 2019-09-08  Injured Reserve  MIN
# 4       Matthew Bosher  atl  2019 2019-09-08              NaN  MIN    NaN
# ..                 ...  ...   ...        ...              ...  ...    ...
# 651       Luke Stocker  atl  2019 2019-12-29              NaN  TAM    NaN
# 652    Desmond Trufant  atl  2019 2019-12-29  Injured Reserve  TAM
# 653        J.J. Wilcox  atl  2019 2019-12-29  Injured Reserve  TAM
# 654          Matt Wile  atl  2019 2019-12-29              NaN  TAM    NaN
# 655  Blidi Wreh-Wilson  atl  2019 2019-12-29              NaN  TAM    NaN
#
# [656 rows x 7 columns]}
